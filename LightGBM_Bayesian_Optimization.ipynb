# %% [markdown]
# # 2023 전력사용량 예측 AI 경진대회 - cgahn0323

# %% [markdown]
# ## Python & Library version check

# %%
# !pip install sktime
# !pip install lightgbm==3.2.1
# !pip install bayesian-optimization
# Out:
# Collecting sktime
#   Downloading sktime-0.22.0-py3-none-any.whl (17.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 53.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.26,>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.23.5)
# Requirement already satisfied: pandas<2.1.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sktime) (23.1)
# Collecting scikit-base<0.6.0 (from sktime)
#   Downloading scikit_base-0.5.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn<1.4.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.2.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.1.0,>=1.1.0->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.1.0,>=1.1.0->sktime) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.4.0,>=0.24.0->sktime) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.4.0,>=0.24.0->sktime) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.1.0,>=1.1.0->sktime) (1.16.0)
# Installing collected packages: scikit-base, sktime
# Successfully installed scikit-base-0.5.1 sktime-0.22.0
# Collecting lightgbm==3.2.1
#   Downloading lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.2.1) (0.41.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.2.1) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.2.1) (1.10.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.2.1) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.2.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.2.1) (3.2.0)
# Installing collected packages: lightgbm
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 4.0.0
#     Uninstalling lightgbm-4.0.0:
#       Successfully uninstalled lightgbm-4.0.0
# Successfully installed lightgbm-3.2.1
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-1.4.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.23.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.2.2)
# Collecting colorama>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (3.2.0)
# Installing collected packages: colorama, bayesian-optimization
# Successfully installed bayesian-optimization-1.4.3 colorama-0.4.6

# %%
import os
import sys
import time
import pandas as pd
import numpy as np
import json
import zipfile
import random
import gc

from bayes_opt import BayesianOptimization
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs

import warnings
warnings.filterwarnings('ignore')

from sktime.utils.plotting import plot_series
import lightgbm as lgb

import gdown

# %%
print("Python version: {}".format(sys.version))
# Out:
# Python version: 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]

# %%
import pkg_resources

def list_installed_packages():
    installed_packages = pkg_resources.working_set
    installed_packages_list = sorted(["%s==%s" % (i.key, i.version) for i in installed_packages])
    for package in installed_packages_list:
        print(package)

list_installed_packages()
# Out:
# absl-py==1.4.0
# aiohttp==3.8.5
# aiosignal==1.3.1
# alabaster==0.7.13
# albumentations==1.3.1
# altair==4.2.2
# annotated-types==0.5.0
# anyio==3.7.1
# appdirs==1.4.4
# argon2-cffi-bindings==21.2.0
# argon2-cffi==23.1.0
# array-record==0.4.1
# arviz==0.15.1
# astropy==5.3.2
# astunparse==1.6.3
# async-timeout==4.0.3
# attrs==23.1.0
# audioread==3.0.0
# autograd==1.6.2
# babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.11.2
# bleach==6.0.0
# blinker==1.4
# blis==0.7.10
# blosc2==2.0.0
# bokeh==3.2.2
# branca==0.6.0
# build==0.10.0
# cachecontrol==0.13.1
# cachetools==5.3.1
# catalogue==2.0.9
# certifi==2023.7.22
# cffi==1.15.1
# chardet==5.2.0
# charset-normalizer==3.2.0
# chex==0.1.7
# click-plugins==1.1.1
# click==8.1.7
# cligj==0.7.2
# cloudpickle==2.2.1
# cmake==3.27.2
# cmdstanpy==1.1.0
# colorcet==3.0.1
# colorlover==0.3.0
# community==1.0.0b1
# confection==0.1.1
# cons==0.4.6
# contextlib2==21.6.0
# contourpy==1.1.0
# convertdate==2.4.0
# cryptography==41.0.3
# cufflinks==0.17.3
# cvxopt==1.3.2
# cvxpy==1.3.2
# cycler==0.11.0
# cymem==2.0.7
# cython==0.29.36
# dask==2023.8.1
# datascience==0.17.6
# db-dtypes==1.1.1
# dbus-python==1.2.18
# debugpy==1.6.6
# decorator==4.4.2
# defusedxml==0.7.1
# distributed==2023.8.1
# distro==1.7.0
# dlib==19.24.2
# dm-tree==0.1.8
# docutils==0.18.1
# dopamine-rl==4.0.6
# duckdb==0.8.1
# earthengine-api==0.1.364
# easydict==1.10
# ecos==2.0.12
# editdistance==0.6.2
# en-core-web-sm==3.6.0
# entrypoints==0.4
# ephem==4.1.4
# et-xmlfile==1.1.0
# etils==1.4.1
# etuples==0.3.9
# exceptiongroup==1.1.3
# fastai==2.7.12
# fastcore==1.5.29
# fastdownload==0.0.7
# fastjsonschema==2.18.0
# fastprogress==1.0.3
# fastrlock==0.8.1
# filelock==3.12.2
# fiona==1.9.4.post1
# firebase-admin==5.3.0
# flask==2.2.5
# flatbuffers==23.5.26
# flax==0.7.2
# folium==0.14.0
# fonttools==4.42.1
# frozendict==2.3.8
# frozenlist==1.4.0
# fsspec==2023.6.0
# future==0.18.3
# gast==0.4.0
# gcsfs==2023.6.0
# gdal==3.4.3
# gdown==4.6.6
# gensim==4.3.1
# geographiclib==2.0
# geopandas==0.13.2
# geopy==2.3.0
# gin-config==0.5.0
# glob2==0.7
# google-api-core==2.11.1
# google-api-python-client==2.84.0
# google-auth-httplib2==0.1.0
# google-auth-oauthlib==1.0.0
# google-auth==2.17.3
# google-cloud-bigquery-connection==1.12.1
# google-cloud-bigquery-storage==2.22.0
# google-cloud-bigquery==3.10.0
# google-cloud-core==2.3.3
# google-cloud-datastore==2.15.2
# google-cloud-firestore==2.11.1
# google-cloud-functions==1.13.2
# google-cloud-language==2.9.1
# google-cloud-storage==2.8.0
# google-cloud-translate==3.11.3
# google-colab==1.0.0
# google-crc32c==1.5.0
# google-pasta==0.2.0
# google-resumable-media==2.5.0
# google==2.0.3
# googleapis-common-protos==1.60.0
# googledrivedownloader==0.4
# graphviz==0.20.1
# greenlet==2.0.2
# grpc-google-iam-v1==0.12.6
# grpcio-status==1.48.2
# grpcio==1.57.0
# gspread-dataframe==3.3.1
# gspread==3.4.2
# gym-notices==0.0.8
# gym==0.25.2
# h5netcdf==1.2.0
# h5py==3.9.0
# holidays==0.31
# holoviews==1.17.1
# html5lib==1.1
# httpimport==1.3.1
# httplib2==0.22.0
# humanize==4.7.0
# hyperopt==0.2.7
# idna==3.4
# imageio-ffmpeg==0.4.8
# imageio==2.31.1
# imagesize==1.4.1
# imbalanced-learn==0.10.1
# imgaug==0.4.0
# importlib-metadata==6.8.0
# importlib-resources==6.0.1
# imutils==0.5.4
# inflect==7.0.0
# iniconfig==2.0.0
# intel-openmp==2023.2.0
# ipykernel==5.5.6
# ipython-genutils==0.2.0
# ipython-sql==0.5.0
# ipython==7.34.0
# ipywidgets==7.7.1
# itsdangerous==2.1.2
# jax==0.4.14
# jaxlib==0.4.14+cuda11.cudnn86
# jeepney==0.7.1
# jieba==0.42.1
# jinja2==3.1.2
# joblib==1.3.2
# jsonpickle==3.0.2
# jsonschema-specifications==2023.7.1
# jsonschema==4.19.0
# jupyter-client==6.1.12
# jupyter-console==6.1.0
# jupyter-core==5.3.1
# jupyter-server==1.24.0
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.8
# kaggle==1.5.16
# keras==2.12.0
# keyring==23.5.0
# kiwisolver==1.4.4
# langcodes==3.3.0
# launchpadlib==1.10.16
# lazr.restfulclient==0.14.4
# lazr.uri==1.0.6
# lazy-loader==0.3
# libclang==16.0.6
# librosa==0.10.1
# lightgbm==4.0.0
# linkify-it-py==2.0.2
# lit==16.0.6
# llvmlite==0.39.1
# locket==1.0.0
# logical-unification==0.4.6
# lunarcalendar==0.0.9
# lxml==4.9.3
# markdown-it-py==3.0.0
# markdown==3.4.4
# markupsafe==2.1.3
# matplotlib-inline==0.1.6
# matplotlib-venn==0.11.9
# matplotlib==3.7.1
# mdit-py-plugins==0.4.0
# mdurl==0.1.2
# minikanren==1.0.3
# missingno==0.5.2
# mistune==0.8.4
# mizani==0.9.2
# mkl==2023.2.0
# ml-dtypes==0.2.0
# mlxtend==0.22.0
# more-itertools==10.1.0
# moviepy==1.0.3
# mpmath==1.3.0
# msgpack==1.0.5
# multidict==6.0.4
# multipledispatch==1.0.0
# multitasking==0.0.11
# murmurhash==1.0.9
# music21==9.1.0
# natsort==8.4.0
# nbclassic==1.0.0
# nbclient==0.8.0
# nbconvert==6.5.4
# nbformat==5.9.2
# nest-asyncio==1.5.7
# networkx==3.1
# nibabel==4.0.2
# nltk==3.8.1
# notebook-shim==0.2.3
# notebook==6.5.5
# numba==0.56.4
# numexpr==2.8.5
# numpy==1.23.5
# oauth2client==4.1.3
# oauthlib==3.2.2
# opencv-contrib-python==4.8.0.76
# opencv-python-headless==4.8.0.76
# opencv-python==4.8.0.76
# openpyxl==3.1.2
# opt-einsum==3.3.0
# optax==0.1.7
# orbax-checkpoint==0.3.5
# osqp==0.6.2.post8
# packaging==23.1
# pandas-datareader==0.10.0
# pandas-gbq==0.17.9
# pandas==1.5.3
# pandocfilters==1.5.0
# panel==1.2.1
# param==1.13.0
# parso==0.8.3
# partd==1.4.0
# pathlib==1.0.1
# pathy==0.10.2
# patsy==0.5.3
# pexpect==4.8.0
# pickleshare==0.7.5
# pillow==9.4.0
# pip-tools==6.13.0
# pip==23.1.2
# platformdirs==3.10.0
# plotly==5.15.0
# plotnine==0.12.2
# pluggy==1.2.0
# polars==0.17.3
# pooch==1.7.0
# portpicker==1.5.2
# prefetch-generator==1.0.3
# preshed==3.0.8
# prettytable==3.8.0
# proglog==0.1.10
# progressbar2==4.2.0
# prometheus-client==0.17.1
# promise==2.3
# prompt-toolkit==3.0.39
# prophet==1.1.4
# proto-plus==1.22.3
# protobuf==3.20.3
# psutil==5.9.5
# psycopg2==2.9.7
# ptyprocess==0.7.0
# py-cpuinfo==9.0.0
# py4j==0.10.9.7
# pyarrow==9.0.0
# pyasn1-modules==0.3.0
# pyasn1==0.5.0
# pycocotools==2.0.7
# pycparser==2.21
# pyct==0.5.0
# pydantic-core==2.6.1
# pydantic==2.2.1
# pydata-google-auth==1.8.2
# pydot-ng==2.0.0
# pydot==1.4.2
# pydotplus==2.0.2
# pydrive2==1.6.3
# pydrive==1.3.1
# pyerfa==2.0.0.3
# pygame==2.5.1
# pygments==2.16.1
# pygobject==3.42.1
# pyjwt==2.3.0
# pymc==5.7.2
# pymeeus==0.5.12
# pymystem3==0.2.0
# pyopengl==3.1.7
# pyopenssl==23.2.0
# pyparsing==3.1.1
# pyproj==3.6.0
# pyproject-hooks==1.0.0
# pysocks==1.7.1
# pytensor==2.14.2
# pytest==7.4.0
# python-apt==0.0.0
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==8.0.1
# python-utils==3.7.0
# pytz==2023.3
# pyviz-comms==3.0.0
# pywavelets==1.4.1
# pyyaml==6.0.1
# pyzmq==23.2.1
# qdldl==0.1.7.post0
# qudida==0.0.4
# referencing==0.30.2
# regex==2023.6.3
# requests-oauthlib==1.3.1
# requests==2.31.0
# requirements-parser==0.5.0
# rich==13.5.2
# rpds-py==0.9.2
# rpy2==3.4.2
# rsa==4.9
# scikit-image==0.19.3
# scikit-learn==1.2.2
# scipy==1.10.1
# scs==3.2.3
# seaborn==0.12.2
# secretstorage==3.3.1
# send2trash==1.8.2
# setuptools==67.7.2
# shapely==2.0.1
# six==1.16.0
# sklearn-pandas==2.2.0
# smart-open==6.3.0
# sniffio==1.3.0
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# soundfile==0.12.1
# soupsieve==2.4.1
# soxr==0.3.6
# spacy-legacy==3.0.12
# spacy-loggers==1.0.4
# spacy==3.6.1
# sphinx==5.0.2
# sphinxcontrib-applehelp==1.0.7
# sphinxcontrib-devhelp==1.0.5
# sphinxcontrib-htmlhelp==2.0.4
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.6
# sphinxcontrib-serializinghtml==1.1.9
# sqlalchemy==2.0.20
# sqlparse==0.4.4
# srsly==2.4.7
# statsmodels==0.14.0
# sympy==1.12
# tables==3.8.0
# tabulate==0.9.0
# tbb==2021.10.0
# tblib==2.0.0
# tenacity==8.2.3
# tensorboard-data-server==0.7.1
# tensorboard==2.12.3
# tensorflow-datasets==4.9.2
# tensorflow-estimator==2.12.0
# tensorflow-gcs-config==2.12.0
# tensorflow-hub==0.14.0
# tensorflow-io-gcs-filesystem==0.33.0
# tensorflow-metadata==1.14.0
# tensorflow-probability==0.20.1
# tensorflow==2.12.0
# tensorstore==0.1.41
# termcolor==2.3.0
# terminado==0.17.1
# text-unidecode==1.3
# textblob==0.17.1
# tf-slim==1.1.0
# thinc==8.1.12
# threadpoolctl==3.2.0
# tifffile==2023.8.12
# tinycss2==1.2.1
# toml==0.10.2
# tomli==2.0.1
# toolz==0.12.0
# torch==2.0.1+cu118
# torchaudio==2.0.2+cu118
# torchdata==0.6.1
# torchsummary==1.5.1
# torchtext==0.15.2
# torchvision==0.15.2+cu118
# tornado==6.3.2
# tqdm==4.66.1
# traitlets==5.7.1
# triton==2.0.0
# tweepy==4.13.0
# typer==0.9.0
# types-setuptools==68.1.0.1
# typing-extensions==4.7.1
# tzlocal==5.0.1
# uc-micro-py==1.0.2
# uritemplate==4.1.1
# urllib3==2.0.4
# vega-datasets==0.9.0
# wadllib==1.3.6
# wasabi==1.1.2
# wcwidth==0.2.6
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.6.2
# werkzeug==2.3.7
# wheel==0.41.2
# widgetsnbextension==3.6.5
# wordcloud==1.9.2
# wrapt==1.14.1
# xarray-einstats==0.6.0
# xarray==2023.7.0
# xgboost==1.7.6
# xlrd==2.0.1
# xyzservices==2023.7.0
# yarl==1.9.2
# yellowbrick==1.5
# yfinance==0.2.28
# zict==3.0.0
# zipp==3.16.2

# %% [markdown]
# # Function Define

# %%
# 결측값 채우기 함수
def fillna_with_group_neighbor_mean(group):
    mask = group.isnull()
    prev = group.shift(1)
    next_ = group.shift(-1)
    group[mask] = ((prev + next_) / 2)[mask]
    return group

# 이상치 수정 함수
def fill_outlier_with_group_neighbor_ratio(group):
    group_median = np.median(group)
    group_std = np.std(group)
    down_mask = group < group_median - 3*group_std
    group[down_mask] = group_median - 3*group_std
    return group

# pre-processing 함수
def preprocess_and_create_features(train, test, month=-1, valid_cut_day=-1, test_cut_day=-1, lag=0, befor_815=True, for_Bayesian_Optimization=False):

    # merge train+test
    df = pd.concat([train,test],axis=0, ignore_index=True)

    # 결측값 처리
    df['풍속(m/s)'] = df.groupby(['건물번호'])['풍속(m/s)'].transform(fillna_with_group_neighbor_mean)
    df['습도(%)'] = df.groupby(['건물번호'])['습도(%)'].transform(fillna_with_group_neighbor_mean)
    df.fillna(0,inplace=True)

    # 이상값 처리
    if for_Bayesian_Optimization:
        df['전력소비량(kWh)'] = df.groupby(['건물번호'])['전력소비량(kWh)'].transform(fill_outlier_with_group_neighbor_ratio)

    #####################################################################################################

    # datetime feature
    df['일시'] = pd.to_datetime(df['일시'], format='%Y%m%d %H')
    df['wday'] = df['일시'].dt.weekday
    df["weekend"] = np.where(df["wday"] < 5, 0, 1)
    df['month'] = df['일시'].dt.month
    df['day'] = df['일시'].dt.day
    df['time'] = df['일시'].dt.hour
    df['wm'] = df['day'].apply(lambda x: np.ceil(x/7))

    #####################################################################################################

    # drop befor 6/6
    df = df.loc[((df['month']>6) | (df['day']>6))].copy()

    # sort & drop
    df.sort_values('일시', inplace=True)
    df.drop(['num_date_time','일시'],axis=1,inplace=True)

    #####################################################################################################

    # Statistics feature

    if befor_815:
        power_cal_df = df.loc[((df['month']<8) | (df['day']<15))].copy()
    else:
        power_cal_df = df

    time_wday_mean = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time', 'wday'], aggfunc = np.mean).reset_index().rename(columns={'전력소비량(kWh)':'time_wday_mean'})
    time_wday_min = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time', 'wday'], aggfunc = np.min).reset_index().rename(columns={'전력소비량(kWh)':'time_wday_min'})
    time_wday_max = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time', 'wday'], aggfunc = np.max).reset_index().rename(columns={'전력소비량(kWh)':'time_wday_max'})
    time_wday_std = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time', 'wday'], aggfunc = np.std).reset_index().rename(columns={'전력소비량(kWh)':'time_wday_std'})
    df = pd.merge(df,time_wday_mean, on=['건물번호', 'time', 'wday'], how='left')
    df = pd.merge(df,time_wday_min, on=['건물번호', 'time', 'wday'], how='left')
    df = pd.merge(df,time_wday_max, on=['건물번호', 'time', 'wday'], how='left')
    df = pd.merge(df,time_wday_std, on=['건물번호', 'time', 'wday'], how='left')

    time_weekend_mean = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time', 'weekend'], aggfunc = np.mean).reset_index().rename(columns={'전력소비량(kWh)':'time_weekend_mean'})
    time_weekend_min = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time', 'weekend'], aggfunc = np.min).reset_index().rename(columns={'전력소비량(kWh)':'time_weekend_min'})
    time_weekend_max = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time', 'weekend'], aggfunc = np.max).reset_index().rename(columns={'전력소비량(kWh)':'time_weekend_max'})
    time_weekend_std = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time', 'weekend'], aggfunc = np.std).reset_index().rename(columns={'전력소비량(kWh)':'time_weekend_std'})
    df = pd.merge(df,time_weekend_mean, on=['건물번호', 'time', 'weekend'], how='left')
    df = pd.merge(df,time_weekend_min, on=['건물번호', 'time', 'weekend'], how='left')
    df = pd.merge(df,time_weekend_max, on=['건물번호', 'time', 'weekend'], how='left')
    df = pd.merge(df,time_weekend_std, on=['건물번호', 'time', 'weekend'], how='left')

    time_mean = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time'], aggfunc = np.mean).reset_index().rename(columns={'전력소비량(kWh)':'time_mean'})
    time_min = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time'], aggfunc = np.min).reset_index().rename(columns={'전력소비량(kWh)':'time_min'})
    time_max = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time'], aggfunc = np.max).reset_index().rename(columns={'전력소비량(kWh)':'time_max'})
    time_std = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'time'], aggfunc = np.std).reset_index().rename(columns={'전력소비량(kWh)':'time_std'})
    df = pd.merge(df,time_mean, on=['건물번호', 'time'], how='left')
    df = pd.merge(df,time_min, on=['건물번호', 'time'], how='left')
    df = pd.merge(df,time_max, on=['건물번호', 'time'], how='left')
    df = pd.merge(df,time_std, on=['건물번호', 'time'], how='left')

    weekend_mean = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'weekend'], aggfunc = np.mean).reset_index().rename(columns={'전력소비량(kWh)':'weekend_mean'})
    weekend_min = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'weekend'], aggfunc = np.min).reset_index().rename(columns={'전력소비량(kWh)':'weekend_min'})
    weekend_max = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'weekend'], aggfunc = np.max).reset_index().rename(columns={'전력소비량(kWh)':'weekend_max'})
    weekend_std = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'weekend'], aggfunc = np.std).reset_index().rename(columns={'전력소비량(kWh)':'weekend_std'})
    df = pd.merge(df,weekend_mean, on=['건물번호', 'weekend'], how='left')
    df = pd.merge(df,weekend_min, on=['건물번호', 'weekend'], how='left')
    df = pd.merge(df,weekend_max, on=['건물번호', 'weekend'], how='left')
    df = pd.merge(df,weekend_std, on=['건물번호', 'weekend'], how='left')

    wday_mean = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'wday'], aggfunc = np.mean).reset_index().rename(columns={'전력소비량(kWh)':'wday_mean'})
    wday_min = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'wday'], aggfunc = np.min).reset_index().rename(columns={'전력소비량(kWh)':'wday_min'})
    wday_max = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'wday'], aggfunc = np.max).reset_index().rename(columns={'전력소비량(kWh)':'wday_max'})
    wday_std = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'wday'], aggfunc = np.std).reset_index().rename(columns={'전력소비량(kWh)':'wday_std'})
    df = pd.merge(df,wday_mean, on=['건물번호', 'wday'], how='left')
    df = pd.merge(df,wday_min, on=['건물번호', 'wday'], how='left')
    df = pd.merge(df,wday_max, on=['건물번호', 'wday'], how='left')
    df = pd.merge(df,wday_std, on=['건물번호', 'wday'], how='left')

    wm_mean = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'wm'], aggfunc = np.mean).reset_index().rename(columns={'전력소비량(kWh)':'wm_mean'})
    wm_min = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'wm'], aggfunc = np.min).reset_index().rename(columns={'전력소비량(kWh)':'wm_min'})
    wm_max = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'wm'], aggfunc = np.max).reset_index().rename(columns={'전력소비량(kWh)':'wm_max'})
    wm_std = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'wm'], aggfunc = np.std).reset_index().rename(columns={'전력소비량(kWh)':'wm_std'})
    df = pd.merge(df,wm_mean, on=['건물번호', 'wm'], how='left')
    df = pd.merge(df,wm_min, on=['건물번호', 'wm'], how='left')
    df = pd.merge(df,wm_max, on=['건물번호', 'wm'], how='left')
    df = pd.merge(df,wm_std, on=['건물번호', 'wm'], how='left')

    month_mean = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'month'], aggfunc = np.mean).reset_index().rename(columns={'전력소비량(kWh)':'month_mean'})
    month_min = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'month'], aggfunc = np.min).reset_index().rename(columns={'전력소비량(kWh)':'month_min'})
    month_max = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'month'], aggfunc = np.max).reset_index().rename(columns={'전력소비량(kWh)':'month_max'})
    month_std = pd.pivot_table(power_cal_df, values = '전력소비량(kWh)', index = ['건물번호', 'month'], aggfunc = np.std).reset_index().rename(columns={'전력소비량(kWh)':'month_std'})
    df = pd.merge(df,month_mean, on=['건물번호', 'month'], how='left')
    df = pd.merge(df,month_min, on=['건물번호', 'month'], how='left')
    df = pd.merge(df,month_max, on=['건물번호', 'month'], how='left')
    df = pd.merge(df,month_std, on=['건물번호', 'month'], how='left')

    #####################################################################################################

    # 기온 / 습도 feature
    df["기온_mean"] = df.groupby(["건물번호"])["기온(C)"].transform('mean')
    df["기온_std"] = df.groupby(["건물번호"])["기온(C)"].transform('std')

    df["기온_time_mean"] = df.groupby(["건물번호","time"])["기온(C)"].transform('mean')
    df["기온_time_std"] = df.groupby(["건물번호","time"])["기온(C)"].transform('std')

    df["기온_wday_time_mean"] = df.groupby(["건물번호","wday","time"])["기온(C)"].transform('mean')
    df["기온_wday_time_std"] = df.groupby(["건물번호","wday","time"])["기온(C)"].transform('std')

    df["습도_mean"] = df.groupby(["건물번호"])["습도(%)"].transform('mean')
    df["습도_std"] = df.groupby(["건물번호"])["습도(%)"].transform('std')

    df["습도_time_mean"] = df.groupby(["건물번호","time"])["습도(%)"].transform('mean')
    df["습도_time_std"] = df.groupby(["건물번호","time"])["습도(%)"].transform('std')

    df["습도_wday_time_mean"] = df.groupby(["건물번호","wday","time"])["습도(%)"].transform('mean')
    df["습도_wday_time_std"] = df.groupby(["건물번호","wday","time"])["습도(%)"].transform('std')

    df["강수량_mean"] = df.groupby(["건물번호"])["강수량(mm)"].transform('mean')
    df["강수량_std"] = df.groupby(["건물번호"])["강수량(mm)"].transform('std')

    df["강수량_time_mean"] = df.groupby(["건물번호","time"])["강수량(mm)"].transform('mean')
    df["강수량_time_std"] = df.groupby(["건물번호","time"])["강수량(mm)"].transform('std')

    df["강수량_wday_time_mean"] = df.groupby(["건물번호","wday","time"])["강수량(mm)"].transform('mean')
    df["강수량_wday_time_std"] = df.groupby(["건물번호","wday","time"])["강수량(mm)"].transform('std')

    df["강수량_rolling_24"] = df.groupby(["건물번호"])["강수량(mm)"].transform(lambda x: x.rolling(24, min_periods=1).mean())
    df["강수량_rolling_24_shift_24"] = df.groupby(["건물번호"])["강수량_rolling_24"].transform(lambda x: x.shift(24))

    #####################################################################################################

    # THI feature
    df['THI'] = 9/5*df["기온(C)"] - 0.55*(1-df["습도(%)"]/100)*(9/5*df["습도(%)"]-26)+32

    # CDH feature
    df['CDH_temp>20'] = [temp if temp > 20 else 0 for temp in df["기온(C)"]]
    df['CDH_temp>23'] = [temp if temp > 23 else 0 for temp in df["기온(C)"]]
    df['CDH_temp>26'] = [temp if temp > 26 else 0 for temp in df["기온(C)"]]
    df['CDH_temp>29'] = [temp if temp > 29 else 0 for temp in df["기온(C)"]]
    df['CDH_temp>20_rolling=12'] = df.groupby(["건물번호"])["CDH_temp>20"].transform(lambda x: x.rolling(12, min_periods=1).mean())
    df['CDH_temp>20_rolling=24'] = df.groupby(["건물번호"])["CDH_temp>20"].transform(lambda x: x.rolling(24, min_periods=1).mean())
    df['CDH_temp>23_rolling=12'] = df.groupby(["건물번호"])["CDH_temp>23"].transform(lambda x: x.rolling(12, min_periods=1).mean())
    df['CDH_temp>23_rolling=24'] = df.groupby(["건물번호"])["CDH_temp>23"].transform(lambda x: x.rolling(24, min_periods=1).mean())
    df['CDH_temp>26_rolling=12'] = df.groupby(["건물번호"])["CDH_temp>26"].transform(lambda x: x.rolling(12, min_periods=1).mean())
    df['CDH_temp>26_rolling=24'] = df.groupby(["건물번호"])["CDH_temp>26"].transform(lambda x: x.rolling(24, min_periods=1).mean())
    df['CDH_temp>29_rolling=12'] = df.groupby(["건물번호"])["CDH_temp>29"].transform(lambda x: x.rolling(12, min_periods=1).mean())
    df['CDH_temp>29_rolling=24'] = df.groupby(["건물번호"])["CDH_temp>29"].transform(lambda x: x.rolling(24, min_periods=1).mean())
    df.drop(['CDH_temp>20','CDH_temp>23','CDH_temp>26','CDH_temp>29'], axis=1, inplace=True)

    #####################################################################################################

    # Shift & Recursive feature
    df['shift_d7']   = df.groupby(['건물번호'])['전력소비량(kWh)'].transform(lambda x: x.shift((1+lag)*24))
    df['shift_d7.1']   = df.groupby(['건물번호'])['전력소비량(kWh)'].transform(lambda x: x.shift((1+lag)*24+1))
    df['shift_d7.2']   = df.groupby(['건물번호'])['전력소비량(kWh)'].transform(lambda x: x.shift((1+lag)*24+2))

    df['shift_time_d1']   = df.groupby(['건물번호','time'])['전력소비량(kWh)'].transform(lambda x: x.shift((1+lag)))
    df['shift_time_d2']   = df.groupby(['건물번호','time'])['전력소비량(kWh)'].transform(lambda x: x.shift((2+lag)))
    df['shift_time_d3']   = df.groupby(['건물번호','time'])['전력소비량(kWh)'].transform(lambda x: x.shift((3+lag)))

    df['기온_time_shift_d1']   = df.groupby(['건물번호','time'])['전력소비량(kWh)'].transform(lambda x: x.shift(1))
    df['습도_time_shift_d1']   = df.groupby(['건물번호','time'])['전력소비량(kWh)'].transform(lambda x: x.shift(1))
    df['기온_time_shift_d2']   = df.groupby(['건물번호','time'])['전력소비량(kWh)'].transform(lambda x: x.shift(2))
    df['습도_time_shift_d2']   = df.groupby(['건물번호','time'])['전력소비량(kWh)'].transform(lambda x: x.shift(2))

    #####################################################################################################

    # 태양광 feature drop
    df.drop(['일조(hr)','일사(MJ/m2)'], axis=1, inplace=True)

    #####################################################################################################

    # cyclical encoding
    df['sin_time'] = np.sin(2*np.pi*df['time']/24)
    df['cos_time'] = np.cos(2*np.pi*df['time']/24)

    #####################################################################################################

    if for_Bayesian_Optimization:
        train_ = df.loc[(df['month']<8) | (df['day']<11)].dropna()
        valid_ = df.loc[(df['month']==8) & (df['day']>=11) & ~((df['month']==8) & (df['day']==15))]
        test_ = df.loc[(df['month']==8) & (df['day']>=11) & ~((df['month']==8) & (df['day']==15))]

    elif month > 0 and valid_cut_day > 0 and test_cut_day > 0:
        train_ = df[(df['month']<month) | (df['day']<valid_cut_day)].dropna()
        valid_ = df[(df['month']==month) & (df['day']>=valid_cut_day) & (df['day']<test_cut_day)]
        test_ = df[(df['month']==month) & (df['day']>=test_cut_day)]
    else:
        train_ = df[ (((df['month']<8) | (df['day']<4)) | ((df['month']>8) | (df['day']>=11))) & ((df['month']<8) | (df['day']<25)) ].dropna()
        valid_ = df[(df['month']==8) & (df['day']>=4) & (df['day']<11)]
        test_ = df[(df['month']==8) & (df['day']>=25)]

    return df, train_, valid_, test_

def extract_zip(input_path ,output_path):
    print("Start extracting zip file.")
    with zipfile.ZipFile(input_path, 'r') as zip_file:
        zip_file.extractall(output_path)

def lgbm_smape(y_pred, dataset):
    y_true = dataset.get_label()
    v = 2 * abs(y_pred - y_true) / (abs(y_pred) + abs(y_true))
    smape_val = np.mean(v) * 100
    return 'SMAPE', smape_val, False

def hamming_distance(a, b):
    return sum(x != y for x, y in zip(a, b))

def read_params(b_type, candidate_num=20, model_num=10):
    with open(f"{root_path}/b_num_{b_type}_parmas.json") as json_file:
        temp_list = []
        for line in json_file:
            temp = json.loads(line)
            temp_list.append((temp['target'],temp['params']))
        temp_list = sorted(temp_list, key=lambda x: x[0], reverse=True)

        feature_bool_list = [
            np.array([_[-1] for _ in sorted([(int(key[1:]),round(best_params[key])) for key in best_params if key[0]=='f' and len(key)<4])])
            for best_target, best_params in temp_list
            ]

        matrix = feature_bool_list[:candidate_num]

        selected_indexs = [0]
        selected_rows = [matrix[0]]
        selected_params = [temp_list[0][-1]]
        while len(selected_rows) < model_num:
            target_i, max_hamming_sum = -1E6, -1E6
            for i in range(len(matrix)):
                if i not in selected_indexs:
                    current_hamming_sum = sum(hamming_distance(matrix[i], row) for row in selected_rows)
                    if current_hamming_sum > max_hamming_sum:
                        target_i = i
                        max_hamming_sum = current_hamming_sum
            selected_indexs.append(target_i)
            selected_rows.append(matrix[target_i])
            selected_params.append(temp_list[target_i][-1])

        feature_marker_matrix = []
        for row in selected_rows:
            feature_marker_matrix.append(list(range(12)) + [_+12 for _ in range(len(row)) if row[_]==1])

    return feature_marker_matrix, selected_params

# %% [markdown]
# # Set Root_Path & Unzip DataSet

# %%
# root_path 생성
root_path = './data/'
if not os.path.exists(root_path):
    os.mkdir(root_path)

# %%
# Download open.zip
google_path = 'https://drive.google.com/uc?id='
file_id = '1TrPq66cNYpc6SxGy5MYCRzA4MbT-XehU'
output_path = f"{root_path}open.zip"
gdown.download(google_path+file_id,output_path,quiet=False)

# Unzip files
extract_zip(output_path,root_path)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TrPq66cNYpc6SxGy5MYCRzA4MbT-XehU
# To: /content/data/open.zip
# 100%|██████████| 2.80M/2.80M [00:00<00:00, 192MB/s]
# Start extracting zip file.

# %% [markdown]
# # Bayesian_Optimization for Feature Selection & Hyper Parameter tuning

# %%
# Read DataSet
sample_submission = pd.read_csv(f"{root_path}sample_submission.csv")
train = pd.read_csv(f"{root_path}train.csv")
test = pd.read_csv(f"{root_path}test.csv")
test['전력소비량(kWh)'] = float('nan')

# %%
# DataSet Setting for Bayesian_Optimization
test = train.loc[(train['일시']>'20220811'),test.columns.tolist()]
test_ans = test[['num_date_time','전력소비량(kWh)']].copy()
train = train.loc[train['일시']<'20220811']

# %%
# Pre-Processing Target DataSet for Bayesian_Optimization
df_0, train_0, valid_0, test_0 = preprocess_and_create_features(train, test, for_Bayesian_Optimization=True)

# %%
def LGB(num,
        f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17,f18,f19,f20,
        f21,f22,f23,f24,f25,f26,f27,f28,f29,f30,f31,f32,f33,f34,f35,f36,f37,f38,f39,f40,
        f41,f42,f43,f44,f45,f46,f47,f48,f49,f50,f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,
        f61,f62,f63,f64,f65,f66,f67,f68,f69,
        subsample,
        subsample_freq,
        learning_rate,
        num_leaves,
        min_data_in_leaf,
        feature_fraction,
        max_bin
        ):

    params = {
        'boosting_type': 'gbdt',
        'objective': 'regression',
        'metric': 'mape',
        'subsample': subsample, # 1
        'subsample_freq': int(subsample_freq), # 1
        'learning_rate': 10**learning_rate, # 0.1
        'num_leaves': int(2**num_leaves-1), # 6
        'min_data_in_leaf': int(2**min_data_in_leaf-1), # 6
        'feature_fraction': feature_fraction, # 0.5
        'max_bin': int(2**max_bin), # 100,
        'n_estimators': 30000,
        'boost_from_average': False,
        'verbose': -1,
        'seed' : 777
    }

    functions_marker = [f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17,f18,f19,f20,
                        f21,f22,f23,f24,f25,f26,f27,f28,f29,f30,f31,f32,f33,f34,f35,f36,f37,f38,f39,f40,
                        f41,f42,f43,f44,f45,f46,f47,f48,f49,f50,f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,
                        f61,f62,f63,f64,f65,f66,f67,f68,f69]
    functions_marker = [1 for _ in range(12)] + list(map(lambda a: round(a),functions_marker))

    # Modeling
    full_columns_list = df_0.columns
    features_preprocessing = [full_columns_list[_] for _ in range(len(functions_marker)) if functions_marker[_] == 1]
    train_ = train_0.loc[df_0['건물번호']==num, features_preprocessing].copy()
    valid_ = valid_0.loc[df_0['건물번호']==num, features_preprocessing].copy()
    test_ = test_0.loc[df_0['건물번호']==num, features_preprocessing].copy()

    X_train, y_train = train_.drop('전력소비량(kWh)',axis=1), train_['전력소비량(kWh)']
    X_valid, y_valid = valid_.drop('전력소비량(kWh)',axis=1), valid_['전력소비량(kWh)']
    X_test, y_test = test_.drop("전력소비량(kWh)", axis=1), test_['전력소비량(kWh)']

    # Create model
    model = lgb.train(params=params,
            train_set=lgb.Dataset(X_train, y_train),
            valid_sets=lgb.Dataset(X_valid, y_valid),
            feval=lgbm_smape,
            verbose_eval=500,
            early_stopping_rounds=100)

    # Test predict
    pred_eva = model.predict(X_test)
    ans = X_test[['건물번호','month','day','time']].copy()
    ans['answer'] = pred_eva
    ans = ans.sort_values(['건물번호','month','day','time']).reset_index(drop=True)
    ans['num_date_time'] = ans['건물번호'].astype(str) + "_2022" + ans['month'].map(lambda x: str(x).zfill(2)) + ans['day'].map(lambda x: str(x).zfill(2)) + ' ' + ans['time'].map(lambda x: str(x).zfill(2))

    plot_df = pd.concat([train,test],axis=0, ignore_index=True)
    plot_df = plot_df[plot_df['num_date_time'].isin(ans['num_date_time'])]
    plot_df.loc[:,'pred'] = ans['answer'].values
    plot_df.loc[:,'real'] = test_ans.loc[test_ans['num_date_time'].isin(ans['num_date_time']),'전력소비량(kWh)'].values
    smape_val = np.mean(2 * abs(plot_df['pred'] - plot_df['real']) / (abs(plot_df['pred']) + abs(plot_df['real']))) * 100

    return -smape_val

# %%
def Bayesian_Opt(num, init_points_=25, n_iter_=100):
    params = {'f' + str(i+1): (0, 1) for i in range(69)}
    params['subsample'] = (0.1, 1)
    params['subsample_freq'] = (1, 10)
    params['learning_rate'] = (-2, -0.5)
    params['num_leaves'] = (2, 12)
    params['min_data_in_leaf'] = (2, 12)
    params['feature_fraction'] = (0.1, 1)
    params['max_bin'] = (1,12)

    # Define an inner function that wraps around the LGB function
    def wrapped_LGB(**kwargs):
        return LGB(num=num, **kwargs)

    # Bayesian optimization 객체 생성
    bo = BayesianOptimization(f=wrapped_LGB, pbounds=params, verbose=2, random_state = 777)

    # JSONLogger 객체 인스턴스화
    logger = JSONLogger(path=f"{root_path}b_num_{num}_parmas.json")

    # BayesianOptimization 객체와 이벤트 연결
    bo.subscribe(Events.OPTIMIZATION_STEP, logger)

    # 목표 함수 최대화 과정 수행
    bo.maximize(init_points=init_points_, n_iter=n_iter_) # n_iter=20

    return bo

# %%
# Private_Score 복원 목적 시 True / Bayesian Optimization 직접 실행 원할 시 False
recovery_private_result = True
if recovery_private_result:
    google_path = 'https://drive.google.com/uc?id='
    file_id = '1Tsixe39VwvqcgkQrTV0dL8oE24cgNrBW'
    output_path = f"{root_path}models.zip"
    gdown.download(google_path+file_id,output_path,quiet=False)
    extract_zip(output_path,root_path)
else:
    b_num_list = sorted(list(df_0['건물번호'].unique()))
    for num in b_num_list:
        now_file_list = os.listdir(root_path)
        if f"b_num_{num}_parmas.json" not in now_file_list:
            bo = Bayesian_Opt(num)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Tsixe39VwvqcgkQrTV0dL8oE24cgNrBW
# To: /content/data/models.zip
# 100%|██████████| 4.16M/4.16M [00:00<00:00, 87.3MB/s]
# Start extracting zip file.

# %% [markdown]
# # 8/15 Target Modeling

# %%
# Read DataSet
sample_submission = pd.read_csv(f"{root_path}sample_submission.csv")
train = pd.read_csv(f"{root_path}train.csv")
test = pd.read_csv(f"{root_path}test.csv")
test['전력소비량(kWh)'] = float('nan')

# %%
# 8월 15일 Modeling 위한 DataSet 편집
test_split = train.loc[(train['일시']>'20220815'),test.columns.tolist()]
test_ans = test_split[['num_date_time','전력소비량(kWh)']].copy()
test_split['전력소비량(kWh)'] = float('nan')
test = test_split.copy()
train = train.loc[train['일시']<'20220815']

# %%
ref_params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'mape',
    'subsample': 1,
    'subsample_freq': 1,
    'learning_rate': 0.01,
    'num_leaves': 2**5-1,
    'min_data_in_leaf': 2**8-1,
    'feature_fraction': 1,
    'max_bin': 1024,
    'n_estimators': 50000,
    'boost_from_average': False,
    'verbose': -1,
    'seed' : 777
}

# %%
# 815 Target Modeling
candidate_num = 48
model_num = 20
final_ensemble_cnt = 16
test_cut_day = 15

start_time = time.time()
Recursive_ans_list = []
seed_list = [777]
for seed in seed_list:
    print("--------------------------------")
    print(f"[seed: {seed}]\n")
    ref_params['seed'] = seed

    val_pred_list, val_real_list = [], []
    ans_list = []
    model_list = {}
    test['전력소비량(kWh)'] = float('nan')
    for lag in range(1):
        df_0, train_0, valid_0, test_0 = preprocess_and_create_features(train, test, month=8, valid_cut_day=8, test_cut_day=15, lag=lag)
        b_type_list = sorted(list(df_0['건물번호'].unique()))
        for b_type in b_type_list:
            params = ref_params.copy()
            ans_temp_list = []
            feature_marker_matrix, selected_params = read_params(b_type, candidate_num=candidate_num, model_num=model_num)
            for num in range(len(feature_marker_matrix)):
                try:
                    feature_marker_list, best_params = feature_marker_matrix[num], selected_params[num]
                    feature_list = [df_0.columns[_] for _ in feature_marker_list]
                    df_b_type = df_0.loc[df_0['건물번호']==b_type, feature_list]
                    train_b_type = train_0.loc[train_0['건물번호']==b_type, feature_list]
                    valid_b_type = valid_0.loc[valid_0['건물번호']==b_type, feature_list]
                    test_b_type = test_0.loc[test_0['건물번호']==b_type, feature_list]

                    params['subsample'] = best_params['subsample']
                    params['subsample_freq'] =  int(best_params['subsample_freq'])
                    #params['learning_rate'] =  10**best_params['learning_rate']
                    params['num_leaves'] =  int(2**best_params['num_leaves']-1)
                    params['min_data_in_leaf'] =  int(2**best_params['min_data_in_leaf']-1)
                    params['feature_fraction'] =  best_params['feature_fraction']
                    params['max_bin'] =  int(2**best_params['max_bin'])
                except:
                    print(f"No param json b_type {b_type}...")
                    df_b_type = df_0[df_0['건물번호']==b_type]
                    train_b_type = train_0[train_0['건물번호']==b_type]
                    valid_b_type = valid_0[valid_0['건물번호']==b_type]
                    test_b_type = test_0[test_0['건물번호']==b_type]

                X_train, y_train = train_b_type.drop('전력소비량(kWh)',axis=1), train_b_type['전력소비량(kWh)']
                X_valid, y_valid = valid_b_type.drop('전력소비량(kWh)',axis=1), valid_b_type['전력소비량(kWh)']
                X_test, y_test = test_b_type.drop("전력소비량(kWh)", axis=1), test_b_type['전력소비량(kWh)']

                test_target = test_b_type[(test_b_type['month']==8)&(test_b_type['day']==test_cut_day+lag)]
                X_test_target, y_test_target = test_target.drop('전력소비량(kWh)',axis=1), test_target['전력소비량(kWh)']

                # Create model
                if b_type not in model_list:
                    model_list[b_type] = {}
                if num not in model_list[b_type]:
                    print(f"[day {lag+1}] [b_type {b_type}] [num {num}] Train model ... {(time.time()-start_time)/60:.2f}min")
                    print("--------")

                    model = lgb.train(params=params,
                            train_set=lgb.Dataset(X_train.drop(['건물번호'],axis=1), y_train),
                            valid_sets=lgb.Dataset(X_valid.drop(['건물번호'],axis=1), y_valid),
                            feval=lgbm_smape,
                            verbose_eval=2000,
                            early_stopping_rounds=100)
                    model_list[b_type][num] = model

                    del model
                    gc.collect()

                    print("--------")

                # Validation predict
                pred_val = model_list[b_type][num].predict(X_valid.drop(['건물번호'],axis=1))
                val_pred_list += list(pred_val)
                val_real_list += list(y_valid)
                smape_val = np.mean(2 * abs(pred_val - y_valid) / (abs(pred_val) + abs(y_valid))) * 100

                # Test predict
                pred_eva = model_list[b_type][num].predict(X_test_target.drop(['건물번호'],axis=1))
                ans = X_test_target[['건물번호','month','day','time']].copy()
                ans['answer'] = pred_eva
                ans = ans.sort_values(['건물번호','month','day','time']).reset_index(drop=True)
                ans['num_date_time'] = ans['건물번호'].astype(str) + "_2022" + ans['month'].map(lambda x: str(x).zfill(2)) + ans['day'].map(lambda x: str(x).zfill(2)) + ' ' + ans['time'].map(lambda x: str(x).zfill(2))
                ans_temp_list.append((smape_val,ans))

                del df_b_type, train_b_type, valid_b_type, test_b_type, X_train, y_train, X_valid, y_valid, X_test, y_test, test_target, X_test_target, y_test_target
                gc.collect()

            ans_temp_list = [ans_tuple[-1] for ans_tuple in sorted(ans_temp_list)[:final_ensemble_cnt]]
            ans.loc[:,'answer'] = pd.concat(ans_temp_list,axis=1)[['answer']].median(axis=1)
            ans_list.append(ans)

            # Update TestSet
            print(f"[day {lag+1}] [b_type {b_type}] Update Recursive")
            test.loc[test['num_date_time'].isin(ans['num_date_time']),'전력소비량(kWh)'] = ans['answer'].values
            print("------------------------")

            del ans, smape_val, ans_temp_list
            gc.collect()


        print("--------")
        print("Done\n")

    val_pred_list = np.array(val_pred_list)
    val_real_list = np.array(val_real_list)
    smape_val = np.mean(2 * abs(val_pred_list - val_real_list) / (abs(val_pred_list) + abs(val_real_list))) * 100
    print(f"final_val_SMAPE : {smape_val}")
    print("--------")

    Recursive_ans = pd.concat(ans_list,axis=0,ignore_index=True)
    Recursive_ans = Recursive_ans.sort_values(['건물번호','month','day','time']).reset_index(drop=True)
    Recursive_ans = Recursive_ans[['num_date_time','month','day','time','answer']].copy()
    Recursive_ans_list.append(Recursive_ans['answer'].values)
Recursive_ans['answer'] = np.mean(Recursive_ans_list,axis=0)
Recursive_ans
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# --------
# [day 1] [b_type 60] [num 11] Train model ... 34.12min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1693]	valid_0's mape: 0.064956	valid_0's SMAPE: 6.94945
# --------
# [day 1] [b_type 60] [num 12] Train model ... 34.56min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1204]	valid_0's mape: 0.0636266	valid_0's SMAPE: 6.85524
# --------
# [day 1] [b_type 60] [num 13] Train model ... 34.58min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [821]	valid_0's mape: 0.0676562	valid_0's SMAPE: 7.22451
# --------
# [day 1] [b_type 60] [num 14] Train model ... 34.59min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [621]	valid_0's mape: 0.0569929	valid_0's SMAPE: 6.06963
# --------
# [day 1] [b_type 60] [num 15] Train model ... 34.60min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [847]	valid_0's mape: 0.0644313	valid_0's SMAPE: 6.92194
# --------
# [day 1] [b_type 60] [num 16] Train model ... 34.64min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [966]	valid_0's mape: 0.060282	valid_0's SMAPE: 6.43464
# --------
# [day 1] [b_type 60] [num 17] Train model ... 34.71min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0654194	valid_0's SMAPE: 6.99163
# Early stopping, best iteration is:
# [3056]	valid_0's mape: 0.0654173	valid_0's SMAPE: 6.99141
# --------
# [day 1] [b_type 60] [num 18] Train model ... 35.06min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [954]	valid_0's mape: 0.0711463	valid_0's SMAPE: 7.64921
# --------
# [day 1] [b_type 60] [num 19] Train model ... 35.08min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1596]	valid_0's mape: 0.0667559	valid_0's SMAPE: 7.13321
# --------
# [day 1] [b_type 60] Update Recursive
# ------------------------
# [day 1] [b_type 61] [num 0] Train model ... 35.13min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0362102	valid_0's SMAPE: 3.5971
# Early stopping, best iteration is:
# [2125]	valid_0's mape: 0.0360135	valid_0's SMAPE: 3.57824
# --------
# [day 1] [b_type 61] [num 1] Train model ... 35.15min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [630]	valid_0's mape: 0.043459	valid_0's SMAPE: 4.35304
# --------
# [day 1] [b_type 61] [num 2] Train model ... 35.16min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [763]	valid_0's mape: 0.0339003	valid_0's SMAPE: 3.42296
# --------
# [day 1] [b_type 61] [num 3] Train model ... 35.18min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1234]	valid_0's mape: 0.0427807	valid_0's SMAPE: 4.26908
# --------
# [day 1] [b_type 61] [num 4] Train model ... 35.18min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [657]	valid_0's mape: 0.0318153	valid_0's SMAPE: 3.17616
# --------
# [day 1] [b_type 61] [num 5] Train model ... 35.20min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [788]	valid_0's mape: 0.0397734	valid_0's SMAPE: 4.00801
# --------
# [day 1] [b_type 61] [num 6] Train model ... 35.21min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0329182	valid_0's SMAPE: 3.32785
# Early stopping, best iteration is:
# [2212]	valid_0's mape: 0.0327581	valid_0's SMAPE: 3.31205
# --------
# [day 1] [b_type 61] [num 7] Train model ... 35.23min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1465]	valid_0's mape: 0.0375346	valid_0's SMAPE: 3.77048
# --------
# [day 1] [b_type 61] [num 8] Train model ... 35.25min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1022]	valid_0's mape: 0.0405068	valid_0's SMAPE: 4.08329
# --------
# [day 1] [b_type 61] [num 9] Train model ... 35.27min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1471]	valid_0's mape: 0.0346442	valid_0's SMAPE: 3.47829
# --------
# [day 1] [b_type 61] [num 10] Train model ... 35.31min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1811]	valid_0's mape: 0.0440303	valid_0's SMAPE: 4.45614
# --------
# [day 1] [b_type 61] [num 11] Train model ... 35.33min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [576]	valid_0's mape: 0.0391082	valid_0's SMAPE: 3.92696
# --------
# [day 1] [b_type 61] [num 12] Train model ... 35.33min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1852]	valid_0's mape: 0.0376678	valid_0's SMAPE: 3.7714
# --------
# [day 1] [b_type 61] [num 13] Train model ... 35.34min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [584]	valid_0's mape: 0.0373933	valid_0's SMAPE: 3.78395
# --------
# [day 1] [b_type 61] [num 14] Train model ... 35.35min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0388656	valid_0's SMAPE: 3.89602
# Early stopping, best iteration is:
# [1975]	valid_0's mape: 0.0388421	valid_0's SMAPE: 3.89349
# --------
# [day 1] [b_type 61] [num 15] Train model ... 35.37min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0307438	valid_0's SMAPE: 3.07554
# [4000]	valid_0's mape: 0.029778	valid_0's SMAPE: 2.98259
# Early stopping, best iteration is:
# [4176]	valid_0's mape: 0.0297125	valid_0's SMAPE: 2.97618
# --------
# [day 1] [b_type 61] [num 16] Train model ... 35.40min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1616]	valid_0's mape: 0.0353898	valid_0's SMAPE: 3.52379
# --------
# [day 1] [b_type 61] [num 17] Train model ... 35.41min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [741]	valid_0's mape: 0.0370738	valid_0's SMAPE: 3.68388
# --------
# [day 1] [b_type 61] [num 18] Train model ... 35.45min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1766]	valid_0's mape: 0.0364492	valid_0's SMAPE: 3.64998
# --------
# [day 1] [b_type 61] [num 19] Train model ... 35.47min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [440]	valid_0's mape: 0.0450967	valid_0's SMAPE: 4.49149
# --------
# [day 1] [b_type 61] Update Recursive
# ------------------------
# [day 1] [b_type 62] [num 0] Train model ... 35.53min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0401973	valid_0's SMAPE: 4.01913
# [4000]	valid_0's mape: 0.038223	valid_0's SMAPE: 3.80989
# Early stopping, best iteration is:
# [4818]	valid_0's mape: 0.037741	valid_0's SMAPE: 3.76039
# --------
# [day 1] [b_type 62] [num 1] Train model ... 35.56min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1327]	valid_0's mape: 0.041364	valid_0's SMAPE: 4.14643
# --------
# [day 1] [b_type 62] [num 2] Train model ... 35.58min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1129]	valid_0's mape: 0.039424	valid_0's SMAPE: 3.91278
# --------
# [day 1] [b_type 62] [num 3] Train model ... 35.62min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0453686	valid_0's SMAPE: 4.54778
# Early stopping, best iteration is:
# [1900]	valid_0's mape: 0.0453599	valid_0's SMAPE: 4.54691
# --------
# [day 1] [b_type 62] [num 4] Train model ... 35.71min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [610]	valid_0's mape: 0.0449432	valid_0's SMAPE: 4.50281
# --------
# [day 1] [b_type 62] [num 5] Train model ... 35.73min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1750]	valid_0's mape: 0.0459505	valid_0's SMAPE: 4.59782
# --------
# [day 1] [b_type 62] [num 6] Train model ... 35.80min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1447]	valid_0's mape: 0.0409017	valid_0's SMAPE: 4.09263
# --------
# [day 1] [b_type 62] [num 7] Train model ... 35.83min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1820]	valid_0's mape: 0.0435266	valid_0's SMAPE: 4.30848
# --------
# [day 1] [b_type 62] [num 8] Train model ... 35.85min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1104]	valid_0's mape: 0.0410137	valid_0's SMAPE: 4.09462
# --------
# [day 1] [b_type 62] [num 9] Train model ... 35.89min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0380462	valid_0's SMAPE: 3.7954
# Early stopping, best iteration is:
# [2119]	valid_0's mape: 0.0380127	valid_0's SMAPE: 3.79223
# --------
# [day 1] [b_type 62] [num 10] Train model ... 35.95min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [354]	valid_0's mape: 0.047104	valid_0's SMAPE: 4.77396
# --------
# [day 1] [b_type 62] [num 11] Train model ... 35.97min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [531]	valid_0's mape: 0.0403082	valid_0's SMAPE: 4.05822
# --------
# [day 1] [b_type 62] [num 12] Train model ... 35.98min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1578]	valid_0's mape: 0.0437693	valid_0's SMAPE: 4.39585
# --------
# [day 1] [b_type 62] [num 13] Train model ... 36.00min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [432]	valid_0's mape: 0.0443496	valid_0's SMAPE: 4.44078
# --------
# [day 1] [b_type 62] [num 14] Train model ... 36.02min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [432]	valid_0's mape: 0.0428913	valid_0's SMAPE: 4.31454
# --------
# [day 1] [b_type 62] [num 15] Train model ... 36.03min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0463416	valid_0's SMAPE: 4.65302
# Early stopping, best iteration is:
# [2513]	valid_0's mape: 0.046334	valid_0's SMAPE: 4.65231
# --------
# [day 1] [b_type 62] [num 16] Train model ... 36.29min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [601]	valid_0's mape: 0.0428627	valid_0's SMAPE: 4.30353
# --------
# [day 1] [b_type 62] [num 17] Train model ... 36.35min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [740]	valid_0's mape: 0.039433	valid_0's SMAPE: 3.93849
# --------
# [day 1] [b_type 62] [num 18] Train model ... 36.36min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [463]	valid_0's mape: 0.0405694	valid_0's SMAPE: 4.10002
# --------
# [day 1] [b_type 62] [num 19] Train model ... 36.38min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [775]	valid_0's mape: 0.0497762	valid_0's SMAPE: 4.91987
# --------
# [day 1] [b_type 62] Update Recursive
# ------------------------
# [day 1] [b_type 63] [num 0] Train model ... 36.42min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0370919	valid_0's SMAPE: 3.62557
# Early stopping, best iteration is:
# [2951]	valid_0's mape: 0.0359419	valid_0's SMAPE: 3.51534
# --------
# [day 1] [b_type 63] [num 1] Train model ... 36.44min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [830]	valid_0's mape: 0.0314767	valid_0's SMAPE: 3.16212
# --------
# [day 1] [b_type 63] [num 2] Train model ... 36.45min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1381]	valid_0's mape: 0.0388187	valid_0's SMAPE: 3.93413
# --------
# [day 1] [b_type 63] [num 3] Train model ... 36.45min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [725]	valid_0's mape: 0.0391434	valid_0's SMAPE: 3.92986
# --------
# [day 1] [b_type 63] [num 4] Train model ... 36.49min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [605]	valid_0's mape: 0.0404446	valid_0's SMAPE: 4.02129
# --------
# [day 1] [b_type 63] [num 5] Train model ... 36.52min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [830]	valid_0's mape: 0.034563	valid_0's SMAPE: 3.40453
# --------
# [day 1] [b_type 63] [num 6] Train model ... 36.53min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [468]	valid_0's mape: 0.0431139	valid_0's SMAPE: 4.28884
# --------
# [day 1] [b_type 63] [num 7] Train model ... 36.54min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1720]	valid_0's mape: 0.0392658	valid_0's SMAPE: 3.88426
# --------
# [day 1] [b_type 63] [num 8] Train model ... 36.55min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1708]	valid_0's mape: 0.0342322	valid_0's SMAPE: 3.37734
# --------
# [day 1] [b_type 63] [num 9] Train model ... 36.56min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1363]	valid_0's mape: 0.038391	valid_0's SMAPE: 3.93596
# --------
# [day 1] [b_type 63] [num 10] Train model ... 36.58min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [618]	valid_0's mape: 0.0401245	valid_0's SMAPE: 3.9635
# --------
# [day 1] [b_type 63] [num 11] Train model ... 36.59min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0385222	valid_0's SMAPE: 3.8155
# Early stopping, best iteration is:
# [2413]	valid_0's mape: 0.0380438	valid_0's SMAPE: 3.77043
# --------
# [day 1] [b_type 63] [num 12] Train model ... 36.60min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [382]	valid_0's mape: 0.0400627	valid_0's SMAPE: 3.99459
# --------
# [day 1] [b_type 63] [num 13] Train model ... 36.61min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0371129	valid_0's SMAPE: 3.69551
# Early stopping, best iteration is:
# [2548]	valid_0's mape: 0.0360763	valid_0's SMAPE: 3.5893
# --------
# [day 1] [b_type 63] [num 14] Train model ... 36.64min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [530]	valid_0's mape: 0.0311696	valid_0's SMAPE: 3.10014
# --------
# [day 1] [b_type 63] [num 15] Train model ... 36.64min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [533]	valid_0's mape: 0.0376137	valid_0's SMAPE: 3.71082
# --------
# [day 1] [b_type 63] [num 16] Train model ... 36.65min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [524]	valid_0's mape: 0.0385964	valid_0's SMAPE: 3.8505
# --------
# [day 1] [b_type 63] [num 17] Train model ... 36.66min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0334257	valid_0's SMAPE: 3.28113
# Early stopping, best iteration is:
# [3492]	valid_0's mape: 0.0311684	valid_0's SMAPE: 3.0615
# --------
# [day 1] [b_type 63] [num 18] Train model ... 36.67min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1164]	valid_0's mape: 0.0355556	valid_0's SMAPE: 3.58631
# --------
# [day 1] [b_type 63] [num 19] Train model ... 36.68min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [435]	valid_0's mape: 0.0431082	valid_0's SMAPE: 4.25546
# --------
# [day 1] [b_type 63] Update Recursive
# ------------------------
# [day 1] [b_type 64] [num 0] Train model ... 36.72min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0398324	valid_0's SMAPE: 3.95468
# [4000]	valid_0's mape: 0.0360043	valid_0's SMAPE: 3.57771
# Early stopping, best iteration is:
# [5750]	valid_0's mape: 0.0342551	valid_0's SMAPE: 3.40923
# --------
# [day 1] [b_type 64] [num 1] Train model ... 36.75min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [653]	valid_0's mape: 0.0407886	valid_0's SMAPE: 4.0519
# --------
# [day 1] [b_type 64] [num 2] Train model ... 36.76min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [596]	valid_0's mape: 0.0333573	valid_0's SMAPE: 3.33151
# --------
# [day 1] [b_type 64] [num 3] Train model ... 36.77min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [423]	valid_0's mape: 0.036726	valid_0's SMAPE: 3.73985
# --------
# [day 1] [b_type 64] [num 4] Train model ... 36.80min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0385557	valid_0's SMAPE: 3.81966
# [4000]	valid_0's mape: 0.0340305	valid_0's SMAPE: 3.38028
# [6000]	valid_0's mape: 0.0327965	valid_0's SMAPE: 3.26167
# Early stopping, best iteration is:
# [7894]	valid_0's mape: 0.0320003	valid_0's SMAPE: 3.18644
# --------
# [day 1] [b_type 64] [num 5] Train model ... 36.83min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.036296	valid_0's SMAPE: 3.62259
# Early stopping, best iteration is:
# [2873]	valid_0's mape: 0.0351254	valid_0's SMAPE: 3.5106
# --------
# [day 1] [b_type 64] [num 6] Train model ... 36.85min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1669]	valid_0's mape: 0.0378634	valid_0's SMAPE: 3.75551
# --------
# [day 1] [b_type 64] [num 7] Train model ... 36.87min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1399]	valid_0's mape: 0.0383038	valid_0's SMAPE: 3.80595
# --------
# [day 1] [b_type 64] [num 8] Train model ... 36.91min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [761]	valid_0's mape: 0.0336727	valid_0's SMAPE: 3.36412
# --------
# [day 1] [b_type 64] [num 9] Train model ... 36.92min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1162]	valid_0's mape: 0.04514	valid_0's SMAPE: 4.59193
# --------
# [day 1] [b_type 64] [num 10] Train model ... 36.93min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [460]	valid_0's mape: 0.0405515	valid_0's SMAPE: 4.06266
# --------
# [day 1] [b_type 64] [num 11] Train model ... 36.94min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0320899	valid_0's SMAPE: 3.2053
# Early stopping, best iteration is:
# [3607]	valid_0's mape: 0.0313032	valid_0's SMAPE: 3.12862
# --------
# [day 1] [b_type 64] [num 12] Train model ... 36.99min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0354643	valid_0's SMAPE: 3.5432
# [4000]	valid_0's mape: 0.0336663	valid_0's SMAPE: 3.36831
# Early stopping, best iteration is:
# [4322]	valid_0's mape: 0.0335418	valid_0's SMAPE: 3.35583
# --------
# [day 1] [b_type 64] [num 13] Train model ... 37.02min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0419705	valid_0's SMAPE: 4.18783
# Early stopping, best iteration is:
# [3807]	valid_0's mape: 0.0415203	valid_0's SMAPE: 4.14151
# --------
# [day 1] [b_type 64] [num 14] Train model ... 37.07min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0388221	valid_0's SMAPE: 3.85249
# Early stopping, best iteration is:
# [2881]	valid_0's mape: 0.0379291	valid_0's SMAPE: 3.76533
# --------
# [day 1] [b_type 64] [num 15] Train model ... 37.11min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0369872	valid_0's SMAPE: 3.65795
# [4000]	valid_0's mape: 0.0357792	valid_0's SMAPE: 3.54167
# Early stopping, best iteration is:
# [4090]	valid_0's mape: 0.035764	valid_0's SMAPE: 3.54026
# --------
# [day 1] [b_type 64] [num 16] Train model ... 37.15min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1639]	valid_0's mape: 0.0363807	valid_0's SMAPE: 3.61446
# --------
# [day 1] [b_type 64] [num 17] Train model ... 37.16min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1043]	valid_0's mape: 0.0399545	valid_0's SMAPE: 3.97893
# --------
# [day 1] [b_type 64] [num 18] Train model ... 37.18min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1185]	valid_0's mape: 0.0361935	valid_0's SMAPE: 3.59958
# --------
# [day 1] [b_type 64] [num 19] Train model ... 37.23min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0374384	valid_0's SMAPE: 3.73461
# Early stopping, best iteration is:
# [2164]	valid_0's mape: 0.0367395	valid_0's SMAPE: 3.66818
# --------
# [day 1] [b_type 64] Update Recursive
# ------------------------
# [day 1] [b_type 65] [num 0] Train model ... 37.25min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [443]	valid_0's mape: 0.0574681	valid_0's SMAPE: 5.7478
# --------
# [day 1] [b_type 65] [num 1] Train model ... 37.26min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [434]	valid_0's mape: 0.0729634	valid_0's SMAPE: 7.10683
# --------
# [day 1] [b_type 65] [num 2] Train model ... 37.26min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1727]	valid_0's mape: 0.0613004	valid_0's SMAPE: 5.98615
# --------
# [day 1] [b_type 65] [num 3] Train model ... 37.27min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [458]	valid_0's mape: 0.0611434	valid_0's SMAPE: 5.91065
# --------
# [day 1] [b_type 65] [num 4] Train model ... 37.31min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [675]	valid_0's mape: 0.0556002	valid_0's SMAPE: 5.50064
# --------
# [day 1] [b_type 65] [num 5] Train model ... 37.32min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [666]	valid_0's mape: 0.0652131	valid_0's SMAPE: 6.4114
# --------
# [day 1] [b_type 65] [num 6] Train model ... 37.32min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0597682	valid_0's SMAPE: 5.92231
# Early stopping, best iteration is:
# [2045]	valid_0's mape: 0.0596198	valid_0's SMAPE: 5.9065
# --------
# [day 1] [b_type 65] [num 7] Train model ... 37.33min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [510]	valid_0's mape: 0.0658908	valid_0's SMAPE: 6.40981
# --------
# [day 1] [b_type 65] [num 8] Train model ... 37.34min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [385]	valid_0's mape: 0.0747663	valid_0's SMAPE: 7.18423
# --------
# [day 1] [b_type 65] [num 9] Train model ... 37.35min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [385]	valid_0's mape: 0.0694422	valid_0's SMAPE: 6.93497
# --------
# [day 1] [b_type 65] [num 10] Train model ... 37.36min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [340]	valid_0's mape: 0.0602608	valid_0's SMAPE: 5.88923
# --------
# [day 1] [b_type 65] [num 11] Train model ... 37.36min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [374]	valid_0's mape: 0.0657765	valid_0's SMAPE: 6.4019
# --------
# [day 1] [b_type 65] [num 12] Train model ... 37.37min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [395]	valid_0's mape: 0.0842472	valid_0's SMAPE: 8.18165
# --------
# [day 1] [b_type 65] [num 13] Train model ... 37.38min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [654]	valid_0's mape: 0.0592972	valid_0's SMAPE: 5.83378
# --------
# [day 1] [b_type 65] [num 14] Train model ... 37.39min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [344]	valid_0's mape: 0.0683013	valid_0's SMAPE: 6.72443
# --------
# [day 1] [b_type 65] [num 15] Train model ... 37.40min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [576]	valid_0's mape: 0.0604107	valid_0's SMAPE: 5.94188
# --------
# [day 1] [b_type 65] [num 16] Train model ... 37.43min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [365]	valid_0's mape: 0.0722257	valid_0's SMAPE: 6.9817
# --------
# [day 1] [b_type 65] [num 17] Train model ... 37.44min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [382]	valid_0's mape: 0.0674478	valid_0's SMAPE: 6.51479
# --------
# [day 1] [b_type 65] [num 18] Train model ... 37.44min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [364]	valid_0's mape: 0.0737144	valid_0's SMAPE: 7.13015
# --------
# [day 1] [b_type 65] [num 19] Train model ... 37.46min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [710]	valid_0's mape: 0.0547705	valid_0's SMAPE: 5.40907
# --------
# [day 1] [b_type 65] Update Recursive
# ------------------------
# [day 1] [b_type 66] [num 0] Train model ... 37.48min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [381]	valid_0's mape: 0.0279996	valid_0's SMAPE: 2.81079
# --------
# [day 1] [b_type 66] [num 1] Train model ... 37.51min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [400]	valid_0's mape: 0.0376215	valid_0's SMAPE: 3.77535
# --------
# [day 1] [b_type 66] [num 2] Train model ... 37.52min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [437]	valid_0's mape: 0.0299065	valid_0's SMAPE: 3.00499
# --------
# [day 1] [b_type 66] [num 3] Train model ... 37.53min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [372]	valid_0's mape: 0.0385891	valid_0's SMAPE: 3.93271
# --------
# [day 1] [b_type 66] [num 4] Train model ... 37.54min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [400]	valid_0's mape: 0.0373226	valid_0's SMAPE: 3.77224
# --------
# [day 1] [b_type 66] [num 5] Train model ... 37.55min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [369]	valid_0's mape: 0.0376207	valid_0's SMAPE: 3.80056
# --------
# [day 1] [b_type 66] [num 6] Train model ... 37.55min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [394]	valid_0's mape: 0.0410648	valid_0's SMAPE: 4.15563
# --------
# [day 1] [b_type 66] [num 7] Train model ... 37.56min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [378]	valid_0's mape: 0.0423794	valid_0's SMAPE: 4.29359
# --------
# [day 1] [b_type 66] [num 8] Train model ... 37.57min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [434]	valid_0's mape: 0.0391347	valid_0's SMAPE: 3.92975
# --------
# [day 1] [b_type 66] [num 9] Train model ... 37.58min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [336]	valid_0's mape: 0.0459983	valid_0's SMAPE: 4.6489
# --------
# [day 1] [b_type 66] [num 10] Train model ... 37.58min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [487]	valid_0's mape: 0.0360127	valid_0's SMAPE: 3.62793
# --------
# [day 1] [b_type 66] [num 11] Train model ... 37.59min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [396]	valid_0's mape: 0.0407347	valid_0's SMAPE: 4.09464
# --------
# [day 1] [b_type 66] [num 12] Train model ... 37.60min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [546]	valid_0's mape: 0.0303344	valid_0's SMAPE: 3.04481
# --------
# [day 1] [b_type 66] [num 13] Train model ... 37.60min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [336]	valid_0's mape: 0.0361467	valid_0's SMAPE: 3.67653
# --------
# [day 1] [b_type 66] [num 14] Train model ... 37.61min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [370]	valid_0's mape: 0.0430777	valid_0's SMAPE: 4.37137
# --------
# [day 1] [b_type 66] [num 15] Train model ... 37.62min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [396]	valid_0's mape: 0.0388529	valid_0's SMAPE: 3.89741
# --------
# [day 1] [b_type 66] [num 16] Train model ... 37.62min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [409]	valid_0's mape: 0.0377143	valid_0's SMAPE: 3.78575
# --------
# [day 1] [b_type 66] [num 17] Train model ... 37.63min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [387]	valid_0's mape: 0.0362007	valid_0's SMAPE: 3.64564
# --------
# [day 1] [b_type 66] [num 18] Train model ... 37.64min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [418]	valid_0's mape: 0.0439324	valid_0's SMAPE: 4.43109
# --------
# [day 1] [b_type 66] [num 19] Train model ... 37.65min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [398]	valid_0's mape: 0.0392309	valid_0's SMAPE: 3.9624
# --------
# [day 1] [b_type 66] Update Recursive
# ------------------------
# [day 1] [b_type 67] [num 0] Train model ... 37.66min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [396]	valid_0's mape: 0.0480478	valid_0's SMAPE: 4.82983
# --------
# [day 1] [b_type 67] [num 1] Train model ... 37.67min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [350]	valid_0's mape: 0.0593852	valid_0's SMAPE: 5.94976
# --------
# [day 1] [b_type 67] [num 2] Train model ... 37.71min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [302]	valid_0's mape: 0.0673029	valid_0's SMAPE: 6.75571
# --------
# [day 1] [b_type 67] [num 3] Train model ... 37.72min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [333]	valid_0's mape: 0.0479226	valid_0's SMAPE: 4.85448
# --------
# [day 1] [b_type 67] [num 4] Train model ... 37.73min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [307]	valid_0's mape: 0.0562961	valid_0's SMAPE: 5.68677
# --------
# [day 1] [b_type 67] [num 5] Train model ... 37.74min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [381]	valid_0's mape: 0.0628099	valid_0's SMAPE: 6.31996
# --------
# [day 1] [b_type 67] [num 6] Train model ... 37.75min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [332]	valid_0's mape: 0.0624537	valid_0's SMAPE: 6.20581
# --------
# [day 1] [b_type 67] [num 7] Train model ... 37.76min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [339]	valid_0's mape: 0.0526541	valid_0's SMAPE: 5.33688
# --------
# [day 1] [b_type 67] [num 8] Train model ... 37.77min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [413]	valid_0's mape: 0.046342	valid_0's SMAPE: 4.61606
# --------
# [day 1] [b_type 67] [num 9] Train model ... 37.78min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [374]	valid_0's mape: 0.0473415	valid_0's SMAPE: 4.73191
# --------
# [day 1] [b_type 67] [num 10] Train model ... 37.80min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [364]	valid_0's mape: 0.0578133	valid_0's SMAPE: 5.78855
# --------
# [day 1] [b_type 67] [num 11] Train model ... 37.81min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [423]	valid_0's mape: 0.0527975	valid_0's SMAPE: 5.3153
# --------
# [day 1] [b_type 67] [num 12] Train model ... 37.83min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [360]	valid_0's mape: 0.0594293	valid_0's SMAPE: 5.89512
# --------
# [day 1] [b_type 67] [num 13] Train model ... 37.84min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [337]	valid_0's mape: 0.0539158	valid_0's SMAPE: 5.38382
# --------
# [day 1] [b_type 67] [num 14] Train model ... 37.85min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [330]	valid_0's mape: 0.0553865	valid_0's SMAPE: 5.6229
# --------
# [day 1] [b_type 67] [num 15] Train model ... 37.86min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [351]	valid_0's mape: 0.0496253	valid_0's SMAPE: 4.96482
# --------
# [day 1] [b_type 67] [num 16] Train model ... 37.87min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [341]	valid_0's mape: 0.0613478	valid_0's SMAPE: 6.20721
# --------
# [day 1] [b_type 67] [num 17] Train model ... 37.91min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [355]	valid_0's mape: 0.0463013	valid_0's SMAPE: 4.62748
# --------
# [day 1] [b_type 67] [num 18] Train model ... 37.92min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [342]	valid_0's mape: 0.0504792	valid_0's SMAPE: 5.10764
# --------
# [day 1] [b_type 67] [num 19] Train model ... 37.93min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [379]	valid_0's mape: 0.0567525	valid_0's SMAPE: 5.67217
# --------
# [day 1] [b_type 67] Update Recursive
# ------------------------
# [day 1] [b_type 68] [num 0] Train model ... 37.94min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0430736	valid_0's SMAPE: 4.38043
# Early stopping, best iteration is:
# [2261]	valid_0's mape: 0.0423862	valid_0's SMAPE: 4.31079
# --------
# [day 1] [b_type 68] [num 1] Train model ... 37.96min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0505541	valid_0's SMAPE: 5.1659
# Early stopping, best iteration is:
# [2092]	valid_0's mape: 0.0504339	valid_0's SMAPE: 5.15552
# --------
# [day 1] [b_type 68] [num 2] Train model ... 37.97min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [548]	valid_0's mape: 0.0415171	valid_0's SMAPE: 4.16121
# --------
# [day 1] [b_type 68] [num 3] Train model ... 37.99min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [966]	valid_0's mape: 0.047198	valid_0's SMAPE: 4.73971
# --------
# [day 1] [b_type 68] [num 4] Train model ... 38.00min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1461]	valid_0's mape: 0.0534792	valid_0's SMAPE: 5.35769
# --------
# [day 1] [b_type 68] [num 5] Train model ... 38.19min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [580]	valid_0's mape: 0.0454671	valid_0's SMAPE: 4.50905
# --------
# [day 1] [b_type 68] [num 6] Train model ... 38.21min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [865]	valid_0's mape: 0.0499888	valid_0's SMAPE: 4.9983
# --------
# [day 1] [b_type 68] [num 7] Train model ... 38.24min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1882]	valid_0's mape: 0.0433698	valid_0's SMAPE: 4.39088
# --------
# [day 1] [b_type 68] [num 8] Train model ... 38.27min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0457003	valid_0's SMAPE: 4.60785
# Early stopping, best iteration is:
# [3859]	valid_0's mape: 0.0444266	valid_0's SMAPE: 4.48583
# --------
# [day 1] [b_type 68] [num 9] Train model ... 38.32min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [665]	valid_0's mape: 0.046298	valid_0's SMAPE: 4.69581
# --------
# [day 1] [b_type 68] [num 10] Train model ... 38.33min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1163]	valid_0's mape: 0.0502647	valid_0's SMAPE: 5.0043
# --------
# [day 1] [b_type 68] [num 11] Train model ... 38.34min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [910]	valid_0's mape: 0.0390454	valid_0's SMAPE: 3.92958
# --------
# [day 1] [b_type 68] [num 12] Train model ... 38.35min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0516089	valid_0's SMAPE: 5.17951
# Early stopping, best iteration is:
# [2666]	valid_0's mape: 0.0515484	valid_0's SMAPE: 5.1738
# --------
# [day 1] [b_type 68] [num 13] Train model ... 38.43min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1756]	valid_0's mape: 0.0451833	valid_0's SMAPE: 4.50943
# --------
# [day 1] [b_type 68] [num 14] Train model ... 38.53min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0425346	valid_0's SMAPE: 4.27368
# Early stopping, best iteration is:
# [2185]	valid_0's mape: 0.0425052	valid_0's SMAPE: 4.27075
# --------
# [day 1] [b_type 68] [num 15] Train model ... 38.60min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0432771	valid_0's SMAPE: 4.3334
# Early stopping, best iteration is:
# [3064]	valid_0's mape: 0.0421172	valid_0's SMAPE: 4.21571
# --------
# [day 1] [b_type 68] [num 16] Train model ... 38.62min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [589]	valid_0's mape: 0.0515326	valid_0's SMAPE: 5.21252
# --------
# [day 1] [b_type 68] [num 17] Train model ... 38.64min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0480151	valid_0's SMAPE: 4.80094
# Early stopping, best iteration is:
# [2030]	valid_0's mape: 0.0479944	valid_0's SMAPE: 4.79915
# --------
# [day 1] [b_type 68] [num 18] Train model ... 38.72min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0495921	valid_0's SMAPE: 4.96753
# Early stopping, best iteration is:
# [3322]	valid_0's mape: 0.0488898	valid_0's SMAPE: 4.89855
# --------
# [day 1] [b_type 68] [num 19] Train model ... 38.76min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [427]	valid_0's mape: 0.0454356	valid_0's SMAPE: 4.60341
# --------
# [day 1] [b_type 68] Update Recursive
# ------------------------
# [day 1] [b_type 69] [num 0] Train model ... 38.77min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1191]	valid_0's mape: 0.0228479	valid_0's SMAPE: 2.29281
# --------
# [day 1] [b_type 69] [num 1] Train model ... 38.79min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [510]	valid_0's mape: 0.030166	valid_0's SMAPE: 3.07908
# --------
# [day 1] [b_type 69] [num 2] Train model ... 38.80min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [802]	valid_0's mape: 0.0239706	valid_0's SMAPE: 2.42384
# --------
# [day 1] [b_type 69] [num 3] Train model ... 38.82min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [684]	valid_0's mape: 0.0227123	valid_0's SMAPE: 2.29482
# --------
# [day 1] [b_type 69] [num 4] Train model ... 38.85min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [694]	valid_0's mape: 0.0259417	valid_0's SMAPE: 2.62442
# --------
# [day 1] [b_type 69] [num 5] Train model ... 38.89min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [744]	valid_0's mape: 0.0204736	valid_0's SMAPE: 2.08412
# --------
# [day 1] [b_type 69] [num 6] Train model ... 38.91min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [610]	valid_0's mape: 0.0238936	valid_0's SMAPE: 2.42428
# --------
# [day 1] [b_type 69] [num 7] Train model ... 38.92min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [679]	valid_0's mape: 0.0209204	valid_0's SMAPE: 2.10517
# --------
# [day 1] [b_type 69] [num 8] Train model ... 38.93min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [921]	valid_0's mape: 0.025854	valid_0's SMAPE: 2.60513
# --------
# [day 1] [b_type 69] [num 9] Train model ... 38.95min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [714]	valid_0's mape: 0.026061	valid_0's SMAPE: 2.63983
# --------
# [day 1] [b_type 69] [num 10] Train model ... 38.96min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [637]	valid_0's mape: 0.0237789	valid_0's SMAPE: 2.40922
# --------
# [day 1] [b_type 69] [num 11] Train model ... 38.97min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [764]	valid_0's mape: 0.0214219	valid_0's SMAPE: 2.16761
# --------
# [day 1] [b_type 69] [num 12] Train model ... 38.98min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [848]	valid_0's mape: 0.0273074	valid_0's SMAPE: 2.74804
# --------
# [day 1] [b_type 69] [num 13] Train model ... 39.01min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [906]	valid_0's mape: 0.0265677	valid_0's SMAPE: 2.65715
# --------
# [day 1] [b_type 69] [num 14] Train model ... 39.02min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [889]	valid_0's mape: 0.0252516	valid_0's SMAPE: 2.54842
# --------
# [day 1] [b_type 69] [num 15] Train model ... 39.05min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [829]	valid_0's mape: 0.0246444	valid_0's SMAPE: 2.47808
# --------
# [day 1] [b_type 69] [num 16] Train model ... 39.09min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [758]	valid_0's mape: 0.0281167	valid_0's SMAPE: 2.82745
# --------
# [day 1] [b_type 69] [num 17] Train model ... 39.11min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [762]	valid_0's mape: 0.0293142	valid_0's SMAPE: 2.98088
# --------
# [day 1] [b_type 69] [num 18] Train model ... 39.13min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1022]	valid_0's mape: 0.0251539	valid_0's SMAPE: 2.52245
# --------
# [day 1] [b_type 69] [num 19] Train model ... 39.14min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [750]	valid_0's mape: 0.0308611	valid_0's SMAPE: 3.11288
# --------
# [day 1] [b_type 69] Update Recursive
# ------------------------
# [day 1] [b_type 70] [num 0] Train model ... 39.16min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [531]	valid_0's mape: 0.0835564	valid_0's SMAPE: 9.1047
# --------
# [day 1] [b_type 70] [num 1] Train model ... 39.17min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [388]	valid_0's mape: 0.107823	valid_0's SMAPE: 11.746
# --------
# [day 1] [b_type 70] [num 2] Train model ... 39.17min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [621]	valid_0's mape: 0.0774693	valid_0's SMAPE: 8.31659
# --------
# [day 1] [b_type 70] [num 3] Train model ... 39.18min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [639]	valid_0's mape: 0.0979456	valid_0's SMAPE: 10.4165
# --------
# [day 1] [b_type 70] [num 4] Train model ... 39.19min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [474]	valid_0's mape: 0.0989974	valid_0's SMAPE: 10.8103
# --------
# [day 1] [b_type 70] [num 5] Train model ... 39.20min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [816]	valid_0's mape: 0.0896049	valid_0's SMAPE: 9.51438
# --------
# [day 1] [b_type 70] [num 6] Train model ... 39.22min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [474]	valid_0's mape: 0.0718001	valid_0's SMAPE: 7.7597
# --------
# [day 1] [b_type 70] [num 7] Train model ... 39.23min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [484]	valid_0's mape: 0.0914703	valid_0's SMAPE: 9.9838
# --------
# [day 1] [b_type 70] [num 8] Train model ... 39.23min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [708]	valid_0's mape: 0.0933491	valid_0's SMAPE: 9.99882
# --------
# [day 1] [b_type 70] [num 9] Train model ... 39.29min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [452]	valid_0's mape: 0.0909097	valid_0's SMAPE: 9.9034
# --------
# [day 1] [b_type 70] [num 10] Train model ... 39.30min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [477]	valid_0's mape: 0.0886361	valid_0's SMAPE: 9.77962
# --------
# ...
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [529]	valid_0's mape: 0.0503273	valid_0's SMAPE: 4.9864
# --------
# [day 1] [b_type 97] [num 15] Train model ... 67.11min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [528]	valid_0's mape: 0.0532989	valid_0's SMAPE: 5.28289
# --------
# [day 1] [b_type 97] [num 16] Train model ... 67.11min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [656]	valid_0's mape: 0.0484895	valid_0's SMAPE: 4.90456
# --------
# [day 1] [b_type 97] [num 17] Train model ... 67.12min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [546]	valid_0's mape: 0.0507075	valid_0's SMAPE: 5.02824
# --------
# [day 1] [b_type 97] [num 18] Train model ... 67.13min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [505]	valid_0's mape: 0.0479365	valid_0's SMAPE: 4.79216
# --------
# [day 1] [b_type 97] [num 19] Train model ... 67.13min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1784]	valid_0's mape: 0.0425748	valid_0's SMAPE: 4.28926
# --------
# [day 1] [b_type 97] Update Recursive
# ------------------------
# [day 1] [b_type 98] [num 0] Train model ... 67.18min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0901047	valid_0's SMAPE: 9.32003
# Early stopping, best iteration is:
# [1994]	valid_0's mape: 0.0900607	valid_0's SMAPE: 9.31358
# --------
# [day 1] [b_type 98] [num 1] Train model ... 67.19min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [554]	valid_0's mape: 0.0919967	valid_0's SMAPE: 9.18203
# --------
# [day 1] [b_type 98] [num 2] Train model ... 67.20min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1051]	valid_0's mape: 0.0946242	valid_0's SMAPE: 9.4452
# --------
# [day 1] [b_type 98] [num 3] Train model ... 67.21min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [880]	valid_0's mape: 0.0964394	valid_0's SMAPE: 9.72272
# --------
# [day 1] [b_type 98] [num 4] Train model ... 67.22min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [814]	valid_0's mape: 0.0929359	valid_0's SMAPE: 9.26719
# --------
# [day 1] [b_type 98] [num 5] Train model ... 67.22min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1167]	valid_0's mape: 0.0867421	valid_0's SMAPE: 8.76158
# --------
# [day 1] [b_type 98] [num 6] Train model ... 67.23min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0846669	valid_0's SMAPE: 8.57593
# Early stopping, best iteration is:
# [2008]	valid_0's mape: 0.0846452	valid_0's SMAPE: 8.57365
# --------
# [day 1] [b_type 98] [num 7] Train model ... 67.25min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1333]	valid_0's mape: 0.0879772	valid_0's SMAPE: 8.9207
# --------
# [day 1] [b_type 98] [num 8] Train model ... 67.25min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1128]	valid_0's mape: 0.0889608	valid_0's SMAPE: 8.91087
# --------
# [day 1] [b_type 98] [num 9] Train model ... 67.26min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1535]	valid_0's mape: 0.0830339	valid_0's SMAPE: 8.42847
# --------
# [day 1] [b_type 98] [num 10] Train model ... 67.28min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [560]	valid_0's mape: 0.0930048	valid_0's SMAPE: 9.52779
# --------
# [day 1] [b_type 98] [num 11] Train model ... 67.28min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1337]	valid_0's mape: 0.0873687	valid_0's SMAPE: 8.76194
# --------
# [day 1] [b_type 98] [num 12] Train model ... 67.29min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [462]	valid_0's mape: 0.0872414	valid_0's SMAPE: 8.8434
# --------
# [day 1] [b_type 98] [num 13] Train model ... 67.30min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [536]	valid_0's mape: 0.0874424	valid_0's SMAPE: 8.86787
# --------
# [day 1] [b_type 98] [num 14] Train model ... 67.31min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1620]	valid_0's mape: 0.089623	valid_0's SMAPE: 8.95513
# --------
# [day 1] [b_type 98] [num 15] Train model ... 67.32min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1090]	valid_0's mape: 0.0841413	valid_0's SMAPE: 8.57087
# --------
# [day 1] [b_type 98] [num 16] Train model ... 67.33min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [845]	valid_0's mape: 0.0959284	valid_0's SMAPE: 9.54057
# --------
# [day 1] [b_type 98] [num 17] Train model ... 67.34min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [702]	valid_0's mape: 0.087688	valid_0's SMAPE: 8.77638
# --------
# [day 1] [b_type 98] [num 18] Train model ... 67.37min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [890]	valid_0's mape: 0.0857587	valid_0's SMAPE: 8.63595
# --------
# [day 1] [b_type 98] [num 19] Train model ... 67.38min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0845808	valid_0's SMAPE: 8.60096
# Early stopping, best iteration is:
# [2293]	valid_0's mape: 0.0840548	valid_0's SMAPE: 8.55055
# --------
# [day 1] [b_type 98] Update Recursive
# ------------------------
# [day 1] [b_type 99] [num 0] Train model ... 67.39min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [544]	valid_0's mape: 0.0385837	valid_0's SMAPE: 3.84212
# --------
# [day 1] [b_type 99] [num 1] Train model ... 67.41min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [598]	valid_0's mape: 0.0343406	valid_0's SMAPE: 3.43262
# --------
# [day 1] [b_type 99] [num 2] Train model ... 67.43min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [480]	valid_0's mape: 0.0352871	valid_0's SMAPE: 3.54467
# --------
# [day 1] [b_type 99] [num 3] Train model ... 67.45min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [425]	valid_0's mape: 0.0358212	valid_0's SMAPE: 3.59699
# --------
# [day 1] [b_type 99] [num 4] Train model ... 67.46min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [397]	valid_0's mape: 0.0377514	valid_0's SMAPE: 3.78003
# --------
# [day 1] [b_type 99] [num 5] Train model ... 67.47min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1308]	valid_0's mape: 0.0356615	valid_0's SMAPE: 3.56854
# --------
# [day 1] [b_type 99] [num 6] Train model ... 67.48min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [452]	valid_0's mape: 0.0376822	valid_0's SMAPE: 3.793
# --------
# [day 1] [b_type 99] [num 7] Train model ... 67.49min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [433]	valid_0's mape: 0.0377302	valid_0's SMAPE: 3.7813
# --------
# [day 1] [b_type 99] [num 8] Train model ... 67.50min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [409]	valid_0's mape: 0.0393658	valid_0's SMAPE: 3.93378
# --------
# [day 1] [b_type 99] [num 9] Train model ... 67.51min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [451]	valid_0's mape: 0.0381565	valid_0's SMAPE: 3.836
# --------
# [day 1] [b_type 99] [num 10] Train model ... 67.52min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [442]	valid_0's mape: 0.0360108	valid_0's SMAPE: 3.61605
# --------
# [day 1] [b_type 99] [num 11] Train model ... 67.59min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [447]	valid_0's mape: 0.0370659	valid_0's SMAPE: 3.73448
# --------
# [day 1] [b_type 99] [num 12] Train model ... 67.60min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [463]	valid_0's mape: 0.0377414	valid_0's SMAPE: 3.7856
# --------
# [day 1] [b_type 99] [num 13] Train model ... 67.61min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [405]	valid_0's mape: 0.0378741	valid_0's SMAPE: 3.81916
# --------
# [day 1] [b_type 99] [num 14] Train model ... 67.62min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [417]	valid_0's mape: 0.038657	valid_0's SMAPE: 3.90897
# --------
# [day 1] [b_type 99] [num 15] Train model ... 67.63min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [389]	valid_0's mape: 0.0351207	valid_0's SMAPE: 3.53927
# --------
# [day 1] [b_type 99] [num 16] Train model ... 67.64min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [404]	valid_0's mape: 0.0365383	valid_0's SMAPE: 3.69327
# --------
# [day 1] [b_type 99] [num 17] Train model ... 67.65min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [924]	valid_0's mape: 0.0401672	valid_0's SMAPE: 4.06351
# --------
# [day 1] [b_type 99] [num 18] Train model ... 67.66min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [389]	valid_0's mape: 0.0375058	valid_0's SMAPE: 3.73705
# --------
# [day 1] [b_type 99] [num 19] Train model ... 67.67min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [409]	valid_0's mape: 0.037392	valid_0's SMAPE: 3.74348
# --------
# [day 1] [b_type 99] Update Recursive
# ------------------------
# [day 1] [b_type 100] [num 0] Train model ... 67.70min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [530]	valid_0's mape: 0.0440244	valid_0's SMAPE: 4.44603
# --------
# [day 1] [b_type 100] [num 1] Train model ... 67.71min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [537]	valid_0's mape: 0.0411874	valid_0's SMAPE: 4.16447
# --------
# [day 1] [b_type 100] [num 2] Train model ... 67.71min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [537]	valid_0's mape: 0.0396998	valid_0's SMAPE: 4.00779
# --------
# [day 1] [b_type 100] [num 3] Train model ... 67.72min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [545]	valid_0's mape: 0.0466205	valid_0's SMAPE: 4.71676
# --------
# [day 1] [b_type 100] [num 4] Train model ... 67.73min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [521]	valid_0's mape: 0.036137	valid_0's SMAPE: 3.61634
# --------
# [day 1] [b_type 100] [num 5] Train model ... 67.77min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [579]	valid_0's mape: 0.0409961	valid_0's SMAPE: 4.16278
# --------
# [day 1] [b_type 100] [num 6] Train model ... 67.78min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1680]	valid_0's mape: 0.0413668	valid_0's SMAPE: 4.09829
# --------
# [day 1] [b_type 100] [num 7] Train model ... 67.81min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [536]	valid_0's mape: 0.039935	valid_0's SMAPE: 3.9855
# --------
# [day 1] [b_type 100] [num 8] Train model ... 67.81min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [592]	valid_0's mape: 0.0476926	valid_0's SMAPE: 4.70878
# --------
# [day 1] [b_type 100] [num 9] Train model ... 67.82min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [379]	valid_0's mape: 0.0400165	valid_0's SMAPE: 4.07552
# --------
# [day 1] [b_type 100] [num 10] Train model ... 67.83min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [577]	valid_0's mape: 0.0417864	valid_0's SMAPE: 4.12391
# --------
# [day 1] [b_type 100] [num 11] Train model ... 67.85min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [472]	valid_0's mape: 0.0419904	valid_0's SMAPE: 4.1739
# --------
# [day 1] [b_type 100] [num 12] Train model ... 67.86min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [700]	valid_0's mape: 0.0346888	valid_0's SMAPE: 3.47699
# --------
# [day 1] [b_type 100] [num 13] Train model ... 67.87min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [700]	valid_0's mape: 0.0466823	valid_0's SMAPE: 4.79796
# --------
# [day 1] [b_type 100] [num 14] Train model ... 67.88min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [440]	valid_0's mape: 0.0402139	valid_0's SMAPE: 4.01431
# --------
# [day 1] [b_type 100] [num 15] Train model ... 67.96min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [441]	valid_0's mape: 0.0383103	valid_0's SMAPE: 3.85704
# --------
# [day 1] [b_type 100] [num 16] Train model ... 67.97min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [473]	valid_0's mape: 0.0361142	valid_0's SMAPE: 3.64626
# --------
# [day 1] [b_type 100] [num 17] Train model ... 67.99min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [657]	valid_0's mape: 0.0511131	valid_0's SMAPE: 5.04382
# --------
# [day 1] [b_type 100] [num 18] Train model ... 67.99min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [430]	valid_0's mape: 0.0399114	valid_0's SMAPE: 4.02535
# --------
# [day 1] [b_type 100] [num 19] Train model ... 68.01min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [943]	valid_0's mape: 0.0423714	valid_0's SMAPE: 4.18841
# --------
# [day 1] [b_type 100] Update Recursive
# ------------------------
# --------
# Done
#
# final_val_SMAPE : 5.094056374684298
# --------
#         num_date_time  month  day  time       answer
# 0       1_20220815 00      8   15     0  1930.899502
# 1       1_20220815 01      8   15     1  1875.406035
# 2       1_20220815 02      8   15     2  1788.252578
# 3       1_20220815 03      8   15     3  1707.473613
# 4       1_20220815 04      8   15     4  1728.369127
# ...               ...    ...  ...   ...          ...
# 2395  100_20220815 19      8   15    19  1142.708285
# 2396  100_20220815 20      8   15    20  1033.975356
# 2397  100_20220815 21      8   15    21   926.747014
# 2398  100_20220815 22      8   15    22   813.332572
# 2399  100_20220815 23      8   15    23   665.533199
#
# [2400 rows x 5 columns]

# %%
ans_815 = Recursive_ans.copy()
ans_815
# Out:
#         num_date_time  month  day  time       answer
# 0       1_20220815 00      8   15     0  1930.899502
# 1       1_20220815 01      8   15     1  1875.406035
# 2       1_20220815 02      8   15     2  1788.252578
# 3       1_20220815 03      8   15     3  1707.473613
# 4       1_20220815 04      8   15     4  1728.369127
# ...               ...    ...  ...   ...          ...
# 2395  100_20220815 19      8   15    19  1142.708285
# 2396  100_20220815 20      8   15    20  1033.975356
# 2397  100_20220815 21      8   15    21   926.747014
# 2398  100_20220815 22      8   15    22   813.332572
# 2399  100_20220815 23      8   15    23   665.533199
#
# [2400 rows x 5 columns]

# %%
ans_815[['num_date_time','answer']].to_csv(f"{root_path}/ans_815.csv", index=False)

# %% [markdown]
# # Main Modeling

# %%
# Read DataSet, again
train = pd.read_csv(f"{root_path}train.csv")
test = pd.read_csv(f"{root_path}test.csv")
train.loc[train['num_date_time'].isin(ans_815['num_date_time']),'전력소비량(kWh)'] = ans_815['answer'].values
test['전력소비량(kWh)'] = float('nan')

# %%
ref_params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'mape',
    'subsample': 1,
    'subsample_freq': 1,
    'learning_rate': 0.01,
    'num_leaves': 2**5-1,
    'min_data_in_leaf': 2**8-1,
    'feature_fraction': 1,
    'max_bin': 1024,
    'n_estimators': 50000,
    'boost_from_average': False,
    'verbose': -1,
    'seed' : 777
}

# %%
# Main Recursive Modeling
candidate_num = 48
model_num = 20
final_ensemble_cnt = 16
test_cut_day = 25

BO_target_num = []
start_time = time.time()
Recursive_ans_list = []
seed_list = [777]
for seed in seed_list:
    print("--------------------------------")
    print(f"[seed: {seed}]\n")
    ref_params['seed'] = seed

    val_pred_list, val_real_list = [], []
    ans_list = []
    model_list = {}
    test['전력소비량(kWh)'] = float('nan')
    for lag in range(7):
        df_0, train_0, valid_0, test_0 = preprocess_and_create_features(train, test, befor_815=False)
        b_type_list = sorted(list(df_0['건물번호'].unique()))
        for b_type in b_type_list:
            params = ref_params.copy()
            ans_temp_list = []
            feature_marker_matrix, selected_params = read_params(b_type, candidate_num=candidate_num, model_num=model_num)
            for num in range(len(feature_marker_matrix)):
                try:
                    feature_marker_list, best_params = feature_marker_matrix[num], selected_params[num]
                    feature_list = [df_0.columns[_] for _ in feature_marker_list]
                    df_b_type = df_0.loc[df_0['건물번호']==b_type, feature_list]
                    train_b_type = train_0.loc[train_0['건물번호']==b_type, feature_list]
                    valid_b_type = valid_0.loc[valid_0['건물번호']==b_type, feature_list]
                    test_b_type = test_0.loc[test_0['건물번호']==b_type, feature_list]

                    params['subsample'] = best_params['subsample']
                    params['subsample_freq'] =  int(best_params['subsample_freq'])
                    #params['learning_rate'] =  10**best_params['learning_rate']
                    params['num_leaves'] =  int(2**best_params['num_leaves']-1)
                    params['min_data_in_leaf'] =  int(2**best_params['min_data_in_leaf']-1)
                    params['feature_fraction'] =  best_params['feature_fraction']
                    params['max_bin'] =  int(2**best_params['max_bin'])
                except:
                    print(f"No param json b_type {b_type}...")
                    df_b_type = df_0[df_0['건물번호']==b_type]
                    train_b_type = train_0[train_0['건물번호']==b_type]
                    valid_b_type = valid_0[valid_0['건물번호']==b_type]
                    test_b_type = test_0[test_0['건물번호']==b_type]

                X_train, y_train = train_b_type.drop('전력소비량(kWh)',axis=1), train_b_type['전력소비량(kWh)']
                X_valid, y_valid = valid_b_type.drop('전력소비량(kWh)',axis=1), valid_b_type['전력소비량(kWh)']
                X_test, y_test = test_b_type.drop("전력소비량(kWh)", axis=1), test_b_type['전력소비량(kWh)']

                test_target = test_b_type[(test_b_type['month']==8)&(test_b_type['day']==test_cut_day+lag)]
                X_test_target, y_test_target = test_target.drop('전력소비량(kWh)',axis=1), test_target['전력소비량(kWh)']

                # Create model
                if b_type not in model_list:
                    model_list[b_type] = {}
                if num not in model_list[b_type]:
                    print(f"[day {lag+1}] [b_type {b_type}] [num {num}] Train model ... {(time.time()-start_time)/60:.2f}min")
                    print("--------")

                    model = lgb.train(params=params,
                            train_set=lgb.Dataset(X_train.drop(['건물번호'],axis=1), y_train),
                            valid_sets=lgb.Dataset(X_valid.drop(['건물번호'],axis=1), y_valid),
                            feval=lgbm_smape,
                            verbose_eval=2000,
                            early_stopping_rounds=100)
                    model_list[b_type][num] = model

                    del model
                    gc.collect()

                    print("--------")

                # Validation predict
                pred_val = model_list[b_type][num].predict(X_valid.drop(['건물번호'],axis=1))
                val_pred_list += list(pred_val)
                val_real_list += list(y_valid)
                smape_val = np.mean(2 * abs(pred_val - y_valid) / (abs(pred_val) + abs(y_valid))) * 100

                # Test predict
                pred_eva = model_list[b_type][num].predict(X_test_target.drop(['건물번호'],axis=1))
                ans = X_test_target[['건물번호','month','day','time']].copy()
                ans['answer'] = pred_eva
                ans = ans.sort_values(['건물번호','month','day','time']).reset_index(drop=True)
                ans['num_date_time'] = ans['건물번호'].astype(str) + "_2022" + ans['month'].map(lambda x: str(x).zfill(2)) + ans['day'].map(lambda x: str(x).zfill(2)) + ' ' + ans['time'].map(lambda x: str(x).zfill(2))
                ans_temp_list.append((smape_val,ans))

                del df_b_type, train_b_type, valid_b_type, test_b_type, X_train, y_train, X_valid, y_valid, X_test, y_test, test_target, X_test_target, y_test_target
                gc.collect()

            ans_temp_list = [ans_tuple[-1] for ans_tuple in sorted(ans_temp_list)[:final_ensemble_cnt]]
            ans.loc[:,'answer'] = pd.concat(ans_temp_list,axis=1)[['answer']].median(axis=1)
            ans_list.append(ans)

            # Update TestSet
            print(f"[day {lag+1}] [b_type {b_type}] Update Recursive")
            test.loc[test['num_date_time'].isin(ans['num_date_time']),'전력소비량(kWh)'] = ans['answer'].values
            print("------------------------")

            del ans, smape_val, ans_temp_list
            gc.collect()

        print("--------")
        print("Done\n")

    val_pred_list = np.array(val_pred_list)
    val_real_list = np.array(val_real_list)
    smape_val = np.mean(2 * abs(val_pred_list - val_real_list) / (abs(val_pred_list) + abs(val_real_list))) * 100
    print(f"final_val_SMAPE : {smape_val}")
    print("--------")

    Recursive_ans = pd.concat(ans_list,axis=0,ignore_index=True)
    Recursive_ans = Recursive_ans.sort_values(['건물번호','month','day','time']).reset_index(drop=True)
    Recursive_ans = Recursive_ans[['num_date_time','month','day','time','answer']].copy()
    Recursive_ans_list.append(Recursive_ans['answer'].values)
Recursive_ans['answer'] = np.mean(Recursive_ans_list,axis=0)
Recursive_ans
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# --------
# [day 1] [b_type 70] [num 6] Train model ... 53.34min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [346]	valid_0's mape: 0.126714	valid_0's SMAPE: 13.3219
# --------
# [day 1] [b_type 70] [num 7] Train model ... 53.35min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [338]	valid_0's mape: 0.0950127	valid_0's SMAPE: 9.52525
# --------
# [day 1] [b_type 70] [num 8] Train model ... 53.36min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [455]	valid_0's mape: 0.123568	valid_0's SMAPE: 13.0587
# --------
# [day 1] [b_type 70] [num 9] Train model ... 53.38min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [409]	valid_0's mape: 0.121319	valid_0's SMAPE: 12.8006
# --------
# [day 1] [b_type 70] [num 10] Train model ... 53.39min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [374]	valid_0's mape: 0.0966572	valid_0's SMAPE: 10.0014
# --------
# [day 1] [b_type 70] [num 11] Train model ... 53.40min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [371]	valid_0's mape: 0.153409	valid_0's SMAPE: 16.9041
# --------
# [day 1] [b_type 70] [num 12] Train model ... 53.43min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [270]	valid_0's mape: 0.138031	valid_0's SMAPE: 15.1266
# --------
# [day 1] [b_type 70] [num 13] Train model ... 53.44min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [320]	valid_0's mape: 0.106352	valid_0's SMAPE: 10.9679
# --------
# [day 1] [b_type 70] [num 14] Train model ... 53.44min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [315]	valid_0's mape: 0.12685	valid_0's SMAPE: 13.4607
# --------
# [day 1] [b_type 70] [num 15] Train model ... 53.45min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [336]	valid_0's mape: 0.131838	valid_0's SMAPE: 13.8069
# --------
# [day 1] [b_type 70] [num 16] Train model ... 53.45min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [267]	valid_0's mape: 0.135099	valid_0's SMAPE: 14.6245
# --------
# [day 1] [b_type 70] [num 17] Train model ... 53.46min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [276]	valid_0's mape: 0.146567	valid_0's SMAPE: 16.0241
# --------
# [day 1] [b_type 70] [num 18] Train model ... 53.47min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [446]	valid_0's mape: 0.143944	valid_0's SMAPE: 15.3783
# --------
# [day 1] [b_type 70] [num 19] Train model ... 53.47min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [422]	valid_0's mape: 0.135592	valid_0's SMAPE: 14.354
# --------
# [day 1] [b_type 70] Update Recursive
# ------------------------
# [day 1] [b_type 71] [num 0] Train model ... 53.48min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [654]	valid_0's mape: 0.0379304	valid_0's SMAPE: 3.91609
# --------
# [day 1] [b_type 71] [num 1] Train model ... 53.49min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [672]	valid_0's mape: 0.0376429	valid_0's SMAPE: 3.85096
# --------
# [day 1] [b_type 71] [num 2] Train model ... 53.51min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1084]	valid_0's mape: 0.0382677	valid_0's SMAPE: 3.93884
# --------
# [day 1] [b_type 71] [num 3] Train model ... 53.56min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.031989	valid_0's SMAPE: 3.28931
# Early stopping, best iteration is:
# [1951]	valid_0's mape: 0.0319795	valid_0's SMAPE: 3.28834
# --------
# [day 1] [b_type 71] [num 4] Train model ... 53.66min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1513]	valid_0's mape: 0.0374647	valid_0's SMAPE: 3.83589
# --------
# [day 1] [b_type 71] [num 5] Train model ... 53.67min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1136]	valid_0's mape: 0.0391392	valid_0's SMAPE: 3.98712
# --------
# [day 1] [b_type 71] [num 6] Train model ... 53.69min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [799]	valid_0's mape: 0.0338427	valid_0's SMAPE: 3.46116
# --------
# [day 1] [b_type 71] [num 7] Train model ... 53.70min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1287]	valid_0's mape: 0.0316055	valid_0's SMAPE: 3.24538
# --------
# [day 1] [b_type 71] [num 8] Train model ... 53.74min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [850]	valid_0's mape: 0.0350462	valid_0's SMAPE: 3.60268
# --------
# [day 1] [b_type 71] [num 9] Train model ... 53.75min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [636]	valid_0's mape: 0.0371127	valid_0's SMAPE: 3.82177
# --------
# [day 1] [b_type 71] [num 10] Train model ... 53.76min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1176]	valid_0's mape: 0.0349323	valid_0's SMAPE: 3.61342
# --------
# [day 1] [b_type 71] [num 11] Train model ... 53.77min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1047]	valid_0's mape: 0.0350783	valid_0's SMAPE: 3.54563
# --------
# [day 1] [b_type 71] [num 12] Train model ... 53.79min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1190]	valid_0's mape: 0.0341384	valid_0's SMAPE: 3.49761
# --------
# [day 1] [b_type 71] [num 13] Train model ... 53.83min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [680]	valid_0's mape: 0.0359189	valid_0's SMAPE: 3.66121
# --------
# [day 1] [b_type 71] [num 14] Train model ... 53.85min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1165]	valid_0's mape: 0.0369914	valid_0's SMAPE: 3.79942
# --------
# [day 1] [b_type 71] [num 15] Train model ... 53.90min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1451]	valid_0's mape: 0.0323705	valid_0's SMAPE: 3.31858
# --------
# [day 1] [b_type 71] [num 16] Train model ... 53.92min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0448071	valid_0's SMAPE: 4.61024
# Early stopping, best iteration is:
# [2165]	valid_0's mape: 0.0448063	valid_0's SMAPE: 4.61016
# --------
# [day 1] [b_type 71] [num 17] Train model ... 54.49min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [584]	valid_0's mape: 0.0350825	valid_0's SMAPE: 3.59217
# --------
# [day 1] [b_type 71] [num 18] Train model ... 54.53min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1095]	valid_0's mape: 0.0425178	valid_0's SMAPE: 4.35477
# --------
# [day 1] [b_type 71] [num 19] Train model ... 54.54min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1781]	valid_0's mape: 0.0359268	valid_0's SMAPE: 3.66967
# --------
# [day 1] [b_type 71] Update Recursive
# ------------------------
# [day 1] [b_type 72] [num 0] Train model ... 54.56min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1049]	valid_0's mape: 0.0507984	valid_0's SMAPE: 5.23505
# --------
# [day 1] [b_type 72] [num 1] Train model ... 54.56min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1045]	valid_0's mape: 0.0452785	valid_0's SMAPE: 4.6644
# --------
# [day 1] [b_type 72] [num 2] Train model ... 54.59min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [656]	valid_0's mape: 0.0549042	valid_0's SMAPE: 5.67247
# --------
# [day 1] [b_type 72] [num 3] Train model ... 54.61min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [702]	valid_0's mape: 0.05125	valid_0's SMAPE: 5.30848
# --------
# [day 1] [b_type 72] [num 4] Train model ... 54.62min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [655]	valid_0's mape: 0.0552749	valid_0's SMAPE: 5.7255
# --------
# [day 1] [b_type 72] [num 5] Train model ... 54.64min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1028]	valid_0's mape: 0.0503844	valid_0's SMAPE: 5.1932
# --------
# [day 1] [b_type 72] [num 6] Train model ... 54.65min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [888]	valid_0's mape: 0.0516763	valid_0's SMAPE: 5.33025
# --------
# [day 1] [b_type 72] [num 7] Train model ... 54.66min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [995]	valid_0's mape: 0.0562481	valid_0's SMAPE: 5.81332
# --------
# [day 1] [b_type 72] [num 8] Train model ... 54.66min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1355]	valid_0's mape: 0.0457518	valid_0's SMAPE: 4.71111
# --------
# [day 1] [b_type 72] [num 9] Train model ... 54.68min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [851]	valid_0's mape: 0.050394	valid_0's SMAPE: 5.19736
# --------
# [day 1] [b_type 72] [num 10] Train model ... 54.68min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1043]	valid_0's mape: 0.0520802	valid_0's SMAPE: 5.37054
# --------
# [day 1] [b_type 72] [num 11] Train model ... 54.69min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [711]	valid_0's mape: 0.0619932	valid_0's SMAPE: 6.46197
# --------
# [day 1] [b_type 72] [num 12] Train model ... 54.70min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [729]	valid_0's mape: 0.0483049	valid_0's SMAPE: 4.97502
# --------
# [day 1] [b_type 72] [num 13] Train model ... 54.71min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [720]	valid_0's mape: 0.0565868	valid_0's SMAPE: 5.85753
# --------
# [day 1] [b_type 72] [num 14] Train model ... 54.72min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [855]	valid_0's mape: 0.0459497	valid_0's SMAPE: 4.7492
# --------
# [day 1] [b_type 72] [num 15] Train model ... 54.73min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [840]	valid_0's mape: 0.0499459	valid_0's SMAPE: 5.16797
# --------
# [day 1] [b_type 72] [num 16] Train model ... 54.74min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [800]	valid_0's mape: 0.0496184	valid_0's SMAPE: 5.1103
# --------
# [day 1] [b_type 72] [num 17] Train model ... 54.75min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1784]	valid_0's mape: 0.0457702	valid_0's SMAPE: 4.70413
# --------
# [day 1] [b_type 72] [num 18] Train model ... 54.76min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0454851	valid_0's SMAPE: 4.67693
# Early stopping, best iteration is:
# [2983]	valid_0's mape: 0.0418602	valid_0's SMAPE: 4.29996
# --------
# [day 1] [b_type 72] [num 19] Train model ... 54.81min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [742]	valid_0's mape: 0.0443148	valid_0's SMAPE: 4.55755
# --------
# [day 1] [b_type 72] Update Recursive
# ------------------------
# [day 1] [b_type 73] [num 0] Train model ... 54.82min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0404819	valid_0's SMAPE: 4.05842
# Early stopping, best iteration is:
# [2008]	valid_0's mape: 0.0404816	valid_0's SMAPE: 4.05839
# --------
# [day 1] [b_type 73] [num 1] Train model ... 55.29min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [832]	valid_0's mape: 0.0425887	valid_0's SMAPE: 4.2753
# --------
# [day 1] [b_type 73] [num 2] Train model ... 55.40min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1499]	valid_0's mape: 0.0439739	valid_0's SMAPE: 4.40019
# --------
# [day 1] [b_type 73] [num 3] Train model ... 55.69min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [656]	valid_0's mape: 0.0373699	valid_0's SMAPE: 3.72258
# --------
# [day 1] [b_type 73] [num 4] Train model ... 55.73min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [574]	valid_0's mape: 0.0352294	valid_0's SMAPE: 3.5095
# --------
# [day 1] [b_type 73] [num 5] Train model ... 55.75min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [675]	valid_0's mape: 0.0378185	valid_0's SMAPE: 3.76889
# --------
# [day 1] [b_type 73] [num 6] Train model ... 55.84min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [720]	valid_0's mape: 0.0415756	valid_0's SMAPE: 4.18316
# --------
# [day 1] [b_type 73] [num 7] Train model ... 55.86min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [591]	valid_0's mape: 0.0406009	valid_0's SMAPE: 4.06468
# --------
# [day 1] [b_type 73] [num 8] Train model ... 55.88min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [775]	valid_0's mape: 0.0333793	valid_0's SMAPE: 3.33949
# --------
# [day 1] [b_type 73] [num 9] Train model ... 55.89min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [636]	valid_0's mape: 0.0397995	valid_0's SMAPE: 3.97411
# --------
# [day 1] [b_type 73] [num 10] Train model ... 55.90min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1075]	valid_0's mape: 0.0463813	valid_0's SMAPE: 4.67234
# --------
# [day 1] [b_type 73] [num 11] Train model ... 56.17min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1846]	valid_0's mape: 0.0379763	valid_0's SMAPE: 3.76999
# --------
# [day 1] [b_type 73] [num 12] Train model ... 56.21min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [773]	valid_0's mape: 0.0456489	valid_0's SMAPE: 4.56172
# --------
# [day 1] [b_type 73] [num 13] Train model ... 56.26min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [620]	valid_0's mape: 0.0348085	valid_0's SMAPE: 3.50755
# --------
# [day 1] [b_type 73] [num 14] Train model ... 56.27min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [559]	valid_0's mape: 0.0390029	valid_0's SMAPE: 3.8859
# --------
# [day 1] [b_type 73] [num 15] Train model ... 56.28min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [808]	valid_0's mape: 0.0372099	valid_0's SMAPE: 3.71314
# --------
# [day 1] [b_type 73] [num 16] Train model ... 56.32min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [485]	valid_0's mape: 0.0364152	valid_0's SMAPE: 3.63308
# --------
# [day 1] [b_type 73] [num 17] Train model ... 56.33min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1129]	valid_0's mape: 0.0397883	valid_0's SMAPE: 4.00005
# --------
# [day 1] [b_type 73] [num 18] Train model ... 56.47min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [707]	valid_0's mape: 0.0386776	valid_0's SMAPE: 3.84809
# --------
# [day 1] [b_type 73] [num 19] Train model ... 56.50min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [690]	valid_0's mape: 0.0370311	valid_0's SMAPE: 3.68385
# --------
# [day 1] [b_type 73] Update Recursive
# ------------------------
# [day 1] [b_type 74] [num 0] Train model ... 56.53min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [807]	valid_0's mape: 0.0476164	valid_0's SMAPE: 4.74007
# --------
# [day 1] [b_type 74] [num 1] Train model ... 56.54min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [647]	valid_0's mape: 0.0561789	valid_0's SMAPE: 5.61472
# --------
# [day 1] [b_type 74] [num 2] Train model ... 56.61min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [991]	valid_0's mape: 0.0485021	valid_0's SMAPE: 4.85874
# --------
# [day 1] [b_type 74] [num 3] Train model ... 56.62min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [892]	valid_0's mape: 0.0479459	valid_0's SMAPE: 4.82814
# --------
# [day 1] [b_type 74] [num 4] Train model ... 56.63min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1021]	valid_0's mape: 0.0531671	valid_0's SMAPE: 5.19193
# --------
# [day 1] [b_type 74] [num 5] Train model ... 56.64min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1093]	valid_0's mape: 0.0543607	valid_0's SMAPE: 5.3762
# --------
# [day 1] [b_type 74] [num 6] Train model ... 56.77min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [510]	valid_0's mape: 0.051404	valid_0's SMAPE: 5.20627
# --------
# [day 1] [b_type 74] [num 7] Train model ... 56.81min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [926]	valid_0's mape: 0.0469908	valid_0's SMAPE: 4.69746
# --------
# [day 1] [b_type 74] [num 8] Train model ... 56.83min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [887]	valid_0's mape: 0.0583838	valid_0's SMAPE: 5.7482
# --------
# [day 1] [b_type 74] [num 9] Train model ... 56.87min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1065]	valid_0's mape: 0.0539194	valid_0's SMAPE: 5.35223
# --------
# [day 1] [b_type 74] [num 10] Train model ... 56.88min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [940]	valid_0's mape: 0.0591517	valid_0's SMAPE: 5.81415
# --------
# [day 1] [b_type 74] [num 11] Train model ... 56.93min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1062]	valid_0's mape: 0.0471543	valid_0's SMAPE: 4.67314
# --------
# [day 1] [b_type 74] [num 12] Train model ... 56.94min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [769]	valid_0's mape: 0.0545344	valid_0's SMAPE: 5.38038
# --------
# [day 1] [b_type 74] [num 13] Train model ... 57.02min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [962]	valid_0's mape: 0.0444046	valid_0's SMAPE: 4.40919
# --------
# [day 1] [b_type 74] [num 14] Train model ... 57.03min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [850]	valid_0's mape: 0.0542891	valid_0's SMAPE: 5.40049
# --------
# [day 1] [b_type 74] [num 15] Train model ... 57.04min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [685]	valid_0's mape: 0.0502998	valid_0's SMAPE: 4.98829
# --------
# [day 1] [b_type 74] [num 16] Train model ... 57.06min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1095]	valid_0's mape: 0.0569642	valid_0's SMAPE: 5.53118
# --------
# [day 1] [b_type 74] [num 17] Train model ... 57.44min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [690]	valid_0's mape: 0.0467079	valid_0's SMAPE: 4.71656
# --------
# [day 1] [b_type 74] [num 18] Train model ... 57.45min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1128]	valid_0's mape: 0.0452378	valid_0's SMAPE: 4.5249
# --------
# [day 1] [b_type 74] [num 19] Train model ... 57.46min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [575]	valid_0's mape: 0.0545907	valid_0's SMAPE: 5.48571
# --------
# [day 1] [b_type 74] Update Recursive
# ------------------------
# [day 1] [b_type 75] [num 0] Train model ... 57.49min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [733]	valid_0's mape: 0.0440678	valid_0's SMAPE: 4.51146
# --------
# [day 1] [b_type 75] [num 1] Train model ... 57.51min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1214]	valid_0's mape: 0.0375242	valid_0's SMAPE: 3.79708
# --------
# [day 1] [b_type 75] [num 2] Train model ... 57.64min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [696]	valid_0's mape: 0.0454762	valid_0's SMAPE: 4.66483
# --------
# [day 1] [b_type 75] [num 3] Train model ... 57.68min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [849]	valid_0's mape: 0.0490364	valid_0's SMAPE: 5.01024
# --------
# [day 1] [b_type 75] [num 4] Train model ... 57.69min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [757]	valid_0's mape: 0.0369029	valid_0's SMAPE: 3.73872
# --------
# [day 1] [b_type 75] [num 5] Train model ... 57.71min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [832]	valid_0's mape: 0.0441366	valid_0's SMAPE: 4.52335
# --------
# [day 1] [b_type 75] [num 6] Train model ... 57.73min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1015]	valid_0's mape: 0.0402302	valid_0's SMAPE: 4.05832
# --------
# [day 1] [b_type 75] [num 7] Train model ... 57.74min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [763]	valid_0's mape: 0.0404339	valid_0's SMAPE: 4.14306
# --------
# [day 1] [b_type 75] [num 8] Train model ... 57.78min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [637]	valid_0's mape: 0.0407092	valid_0's SMAPE: 4.17987
# --------
# [day 1] [b_type 75] [num 9] Train model ... 57.79min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [560]	valid_0's mape: 0.0437127	valid_0's SMAPE: 4.43328
# --------
# [day 1] [b_type 75] [num 10] Train model ... 57.80min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [758]	valid_0's mape: 0.0475929	valid_0's SMAPE: 4.96382
# --------
# [day 1] [b_type 75] [num 11] Train model ... 57.86min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [652]	valid_0's mape: 0.0399478	valid_0's SMAPE: 4.12014
# --------
# [day 1] [b_type 75] [num 12] Train model ... 57.88min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [633]	valid_0's mape: 0.0463288	valid_0's SMAPE: 4.66287
# --------
# [day 1] [b_type 75] [num 13] Train model ... 57.89min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [504]	valid_0's mape: 0.042425	valid_0's SMAPE: 4.33039
# --------
# [day 1] [b_type 75] [num 14] Train model ... 57.90min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [916]	valid_0's mape: 0.0462528	valid_0's SMAPE: 4.80754
# --------
# [day 1] [b_type 75] [num 15] Train model ... 57.93min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [703]	valid_0's mape: 0.0378447	valid_0's SMAPE: 3.83257
# --------
# [day 1] [b_type 75] [num 16] Train model ... 57.94min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1566]	valid_0's mape: 0.0524847	valid_0's SMAPE: 5.29612
# --------
# [day 1] [b_type 75] [num 17] Train model ... 57.98min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [629]	valid_0's mape: 0.0427931	valid_0's SMAPE: 4.33373
# --------
# [day 1] [b_type 75] [num 18] Train model ... 57.99min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [728]	valid_0's mape: 0.0394542	valid_0's SMAPE: 4.01603
# --------
# [day 1] [b_type 75] [num 19] Train model ... 58.00min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [990]	valid_0's mape: 0.0386255	valid_0's SMAPE: 3.90667
# --------
# [day 1] [b_type 75] Update Recursive
# ------------------------
# [day 1] [b_type 76] [num 0] Train model ... 58.02min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [526]	valid_0's mape: 0.0401962	valid_0's SMAPE: 4.12796
# --------
# [day 1] [b_type 76] [num 1] Train model ... 58.03min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1201]	valid_0's mape: 0.0367649	valid_0's SMAPE: 3.7554
# --------
# [day 1] [b_type 76] [num 2] Train model ... 58.04min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [869]	valid_0's mape: 0.0354523	valid_0's SMAPE: 3.59648
# --------
# [day 1] [b_type 76] [num 3] Train model ... 58.05min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [795]	valid_0's mape: 0.0395489	valid_0's SMAPE: 4.06183
# --------
# [day 1] [b_type 76] [num 4] Train model ... 58.06min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0378046	valid_0's SMAPE: 3.84636
# Early stopping, best iteration is:
# [2173]	valid_0's mape: 0.0377802	valid_0's SMAPE: 3.84443
# --------
# [day 1] [b_type 76] [num 5] Train model ... 58.10min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [680]	valid_0's mape: 0.040838	valid_0's SMAPE: 4.19372
# --------
# [day 1] [b_type 76] [num 6] Train model ... 58.10min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [800]	valid_0's mape: 0.0378782	valid_0's SMAPE: 3.86006
# --------
# [day 1] [b_type 76] [num 7] Train model ... 58.11min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [838]	valid_0's mape: 0.0313963	valid_0's SMAPE: 3.15973
# --------
# [day 1] [b_type 76] [num 8] Train model ... 58.13min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [640]	valid_0's mape: 0.0338046	valid_0's SMAPE: 3.43543
# --------
# [day 1] [b_type 76] [num 9] Train model ... 58.13min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1099]	valid_0's mape: 0.0349575	valid_0's SMAPE: 3.58167
# --------
# [day 1] [b_type 76] [num 10] Train model ... 58.21min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1673]	valid_0's mape: 0.035248	valid_0's SMAPE: 3.57222
# --------
# [day 1] [b_type 76] [num 11] Train model ... 58.22min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [834]	valid_0's mape: 0.0378147	valid_0's SMAPE: 3.85257
# --------
# [day 1] [b_type 76] [num 12] Train model ... 58.23min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [920]	valid_0's mape: 0.0353737	valid_0's SMAPE: 3.62471
# --------
# [day 1] [b_type 76] [num 13] Train model ... 58.28min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1221]	valid_0's mape: 0.0498104	valid_0's SMAPE: 4.99655
# --------
# [day 1] [b_type 76] [num 14] Train model ... 58.29min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [672]	valid_0's mape: 0.039643	valid_0's SMAPE: 4.06147
# --------
# [day 1] [b_type 76] [num 15] Train model ... 58.30min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0377159	valid_0's SMAPE: 3.83445
# Early stopping, best iteration is:
# [3360]	valid_0's mape: 0.0372906	valid_0's SMAPE: 3.79296
# --------
# [day 1] [b_type 76] [num 16] Train model ... 58.32min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0398129	valid_0's SMAPE: 4.04562
# [4000]	valid_0's mape: 0.0366024	valid_0's SMAPE: 3.73216
# Early stopping, best iteration is:
# [4231]	valid_0's mape: 0.0362624	valid_0's SMAPE: 3.69793
# --------
# [day 1] [b_type 76] [num 17] Train model ... 58.36min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1123]	valid_0's mape: 0.0333228	valid_0's SMAPE: 3.39446
# --------
# [day 1] [b_type 76] [num 18] Train model ... 58.38min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1789]	valid_0's mape: 0.0378149	valid_0's SMAPE: 3.85199
# --------
# [day 1] [b_type 76] [num 19] Train model ... 58.39min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [666]	valid_0's mape: 0.0410679	valid_0's SMAPE: 4.20253
# --------
# [day 1] [b_type 76] Update Recursive
# ------------------------
# [day 1] [b_type 77] [num 0] Train model ... 58.40min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0289584	valid_0's SMAPE: 2.8995
# Early stopping, best iteration is:
# [2741]	valid_0's mape: 0.0285222	valid_0's SMAPE: 2.85346
# --------
# [day 1] [b_type 77] [num 1] Train model ... 58.42min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [565]	valid_0's mape: 0.0324523	valid_0's SMAPE: 3.26528
# --------
# [day 1] [b_type 77] [num 2] Train model ... 58.47min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [933]	valid_0's mape: 0.02947	valid_0's SMAPE: 2.97047
# --------
# [day 1] [b_type 77] [num 3] Train model ... 58.48min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [569]	valid_0's mape: 0.02804	valid_0's SMAPE: 2.81613
# --------
# [day 1] [b_type 77] [num 4] Train model ... 58.50min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [707]	valid_0's mape: 0.0268579	valid_0's SMAPE: 2.69648
# --------
# [day 1] [b_type 77] [num 5] Train model ... 58.53min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [552]	valid_0's mape: 0.0276453	valid_0's SMAPE: 2.77041
# --------
# [day 1] [b_type 77] [num 6] Train model ... 58.57min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1807]	valid_0's mape: 0.0261724	valid_0's SMAPE: 2.62283
# --------
# [day 1] [b_type 77] [num 7] Train model ... 58.59min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [804]	valid_0's mape: 0.0273207	valid_0's SMAPE: 2.73978
# --------
# [day 1] [b_type 77] [num 8] Train model ... 58.60min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1057]	valid_0's mape: 0.0296734	valid_0's SMAPE: 2.97936
# --------
# [day 1] [b_type 77] [num 9] Train model ... 58.69min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1148]	valid_0's mape: 0.0275793	valid_0's SMAPE: 2.75925
# --------
# [day 1] [b_type 77] [num 10] Train model ... 58.70min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1502]	valid_0's mape: 0.0269023	valid_0's SMAPE: 2.69266
# --------
# [day 1] [b_type 77] [num 11] Train model ... 58.71min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [629]	valid_0's mape: 0.0283062	valid_0's SMAPE: 2.84189
# --------
# [day 1] [b_type 77] [num 12] Train model ... 58.73min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [810]	valid_0's mape: 0.0287224	valid_0's SMAPE: 2.88183
# --------
# [day 1] [b_type 77] [num 13] Train model ... 58.77min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [603]	valid_0's mape: 0.0269564	valid_0's SMAPE: 2.71565
# --------
# [day 1] [b_type 77] [num 14] Train model ... 58.80min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [792]	valid_0's mape: 0.0263511	valid_0's SMAPE: 2.64608
# --------
# [day 1] [b_type 77] [num 15] Train model ... 58.82min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [771]	valid_0's mape: 0.0286516	valid_0's SMAPE: 2.88333
# --------
# [day 1] [b_type 77] [num 16] Train model ... 59.14min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [630]	valid_0's mape: 0.0277637	valid_0's SMAPE: 2.78901
# --------
# [day 1] [b_type 77] [num 17] Train model ... 59.18min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [685]	valid_0's mape: 0.0280392	valid_0's SMAPE: 2.80895
# --------
# [day 1] [b_type 77] [num 18] Train model ... 59.20min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [857]	valid_0's mape: 0.0270808	valid_0's SMAPE: 2.7206
# --------
# [day 1] [b_type 77] [num 19] Train model ... 59.21min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [576]	valid_0's mape: 0.0288359	valid_0's SMAPE: 2.89097
# --------
# [day 1] [b_type 77] Update Recursive
# ------------------------
# [day 1] [b_type 78] [num 0] Train model ... 59.23min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [904]	valid_0's mape: 0.0256433	valid_0's SMAPE: 2.61073
# --------
# [day 1] [b_type 78] [num 1] Train model ... 59.24min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [744]	valid_0's mape: 0.0329273	valid_0's SMAPE: 3.37426
# --------
# [day 1] [b_type 78] [num 2] Train model ... 59.25min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [929]	valid_0's mape: 0.0295258	valid_0's SMAPE: 3.01989
# --------
# [day 1] [b_type 78] [num 3] Train model ... 59.26min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [825]	valid_0's mape: 0.0263985	valid_0's SMAPE: 2.68203
# --------
# [day 1] [b_type 78] [num 4] Train model ... 59.29min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [798]	valid_0's mape: 0.0282473	valid_0's SMAPE: 2.8778
# --------
# [day 1] [b_type 78] [num 5] Train model ... 59.30min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [583]	valid_0's mape: 0.0276453	valid_0's SMAPE: 2.82057
# --------
# [day 1] [b_type 78] [num 6] Train model ... 59.32min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [940]	valid_0's mape: 0.0320231	valid_0's SMAPE: 3.27382
# --------
# [day 1] [b_type 78] [num 7] Train model ... 59.39min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [833]	valid_0's mape: 0.0291342	valid_0's SMAPE: 2.9755
# --------
# [day 1] [b_type 78] [num 8] Train model ... 59.46min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1007]	valid_0's mape: 0.0275776	valid_0's SMAPE: 2.81093
# --------
# [day 1] [b_type 78] [num 9] Train model ... 59.48min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [903]	valid_0's mape: 0.0347689	valid_0's SMAPE: 3.56853
# --------
# [day 1] [b_type 78] [num 10] Train model ... 59.50min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1564]	valid_0's mape: 0.0243785	valid_0's SMAPE: 2.47716
# --------
# [day 1] [b_type 78] [num 11] Train model ... 59.51min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [765]	valid_0's mape: 0.0242517	valid_0's SMAPE: 2.47087
# --------
# [day 1] [b_type 78] [num 12] Train model ... 59.57min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [656]	valid_0's mape: 0.0266827	valid_0's SMAPE: 2.72319
# --------
# [day 1] [b_type 78] [num 13] Train model ... 59.61min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [919]	valid_0's mape: 0.0277256	valid_0's SMAPE: 2.83129
# --------
# [day 1] [b_type 78] [num 14] Train model ... 59.66min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1047]	valid_0's mape: 0.0257822	valid_0's SMAPE: 2.6201
# --------
# [day 1] [b_type 78] [num 15] Train model ... 59.67min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [781]	valid_0's mape: 0.0281431	valid_0's SMAPE: 2.86982
# --------
# [day 1] [b_type 78] [num 16] Train model ... 59.70min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [772]	valid_0's mape: 0.0280181	valid_0's SMAPE: 2.84883
# --------
# [day 1] [b_type 78] [num 17] Train model ... 59.72min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1018]	valid_0's mape: 0.0263497	valid_0's SMAPE: 2.682
# --------
# [day 1] [b_type 78] [num 18] Train model ... 59.76min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [921]	valid_0's mape: 0.0279678	valid_0's SMAPE: 2.85325
# --------
# [day 1] [b_type 78] [num 19] Train model ... 59.77min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [903]	valid_0's mape: 0.0264456	valid_0's SMAPE: 2.70199
# --------
# [day 1] [b_type 78] Update Recursive
# ------------------------
# [day 1] [b_type 79] [num 0] Train model ... 59.79min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [983]	valid_0's mape: 0.0209541	valid_0's SMAPE: 2.11642
# --------
# [day 1] [b_type 79] [num 1] Train model ... 59.81min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [996]	valid_0's mape: 0.0246536	valid_0's SMAPE: 2.48956
# --------
# [day 1] [b_type 79] [num 2] Train model ... 59.82min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1108]	valid_0's mape: 0.0228291	valid_0's SMAPE: 2.29996
# --------
# [day 1] [b_type 79] [num 3] Train model ... 59.84min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1155]	valid_0's mape: 0.0240878	valid_0's SMAPE: 2.41372
# --------
# [day 1] [b_type 79] [num 4] Train model ... 59.85min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [822]	valid_0's mape: 0.0277628	valid_0's SMAPE: 2.82421
# --------
# [day 1] [b_type 79] [num 5] Train model ... 59.86min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [755]	valid_0's mape: 0.0237647	valid_0's SMAPE: 2.40002
# --------
# [day 1] [b_type 79] [num 6] Train model ... 59.87min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1089]	valid_0's mape: 0.024405	valid_0's SMAPE: 2.47587
# --------
# [day 1] [b_type 79] [num 7] Train model ... 59.88min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0240364	valid_0's SMAPE: 2.42103
# Early stopping, best iteration is:
# [2565]	valid_0's mape: 0.023816	valid_0's SMAPE: 2.39841
# --------
# [day 1] [b_type 79] [num 8] Train model ... 59.90min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [831]	valid_0's mape: 0.0235033	valid_0's SMAPE: 2.38255
# --------
# [day 1] [b_type 79] [num 9] Train model ... 59.92min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [615]	valid_0's mape: 0.0249667	valid_0's SMAPE: 2.52195
# --------
# [day 1] [b_type 79] [num 10] Train model ... 59.95min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [754]	valid_0's mape: 0.0226289	valid_0's SMAPE: 2.27952
# --------
# [day 1] [b_type 79] [num 11] Train model ... 59.96min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [804]	valid_0's mape: 0.0237177	valid_0's SMAPE: 2.40145
# --------
# [day 1] [b_type 79] [num 12] Train model ... 59.97min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [804]	valid_0's mape: 0.0227662	valid_0's SMAPE: 2.29942
# --------
# [day 1] [b_type 79] [num 13] Train model ... 59.98min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [846]	valid_0's mape: 0.0252405	valid_0's SMAPE: 2.55003
# --------
# [day 1] [b_type 79] [num 14] Train model ... 60.01min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [764]	valid_0's mape: 0.0245113	valid_0's SMAPE: 2.48003
# --------
# [day 1] [b_type 79] [num 15] Train model ... 60.06min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [838]	valid_0's mape: 0.0242984	valid_0's SMAPE: 2.45864
# --------
# [day 1] [b_type 79] [num 16] Train model ... 60.09min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [688]	valid_0's mape: 0.0248174	valid_0's SMAPE: 2.51709
# --------
# [day 1] [b_type 79] [num 17] Train model ... 60.10min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [668]	valid_0's mape: 0.0219883	valid_0's SMAPE: 2.23499
# --------
# [day 1] [b_type 79] [num 18] Train model ... 60.11min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1305]	valid_0's mape: 0.0245473	valid_0's SMAPE: 2.49113
# --------
# [day 1] [b_type 79] [num 19] Train model ... 60.14min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1234]	valid_0's mape: 0.0235638	valid_0's SMAPE: 2.38774
# --------
# [day 1] [b_type 79] Update Recursive
# ------------------------
# [day 1] [b_type 80] [num 0] Train model ... 60.16min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [958]	valid_0's mape: 0.0379698	valid_0's SMAPE: 3.90128
# --------
# [day 1] [b_type 80] [num 1] Train model ... 60.19min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1191]	valid_0's mape: 0.0365281	valid_0's SMAPE: 3.74555
# --------
# [day 1] [b_type 80] [num 2] Train model ... 60.21min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1185]	valid_0's mape: 0.0453415	valid_0's SMAPE: 4.69992
# --------
# [day 1] [b_type 80] [num 3] Train model ... 60.80min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1624]	valid_0's mape: 0.0387681	valid_0's SMAPE: 4.00381
# --------
# [day 1] [b_type 80] [num 4] Train model ... 61.17min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1014]	valid_0's mape: 0.0421148	valid_0's SMAPE: 4.33459
# --------
# [day 1] [b_type 80] [num 5] Train model ... 61.19min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1258]	valid_0's mape: 0.0419324	valid_0's SMAPE: 4.34926
# --------
# [day 1] [b_type 80] [num 6] Train model ... 61.63min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0332902	valid_0's SMAPE: 3.39679
# Early stopping, best iteration is:
# [2909]	valid_0's mape: 0.0324225	valid_0's SMAPE: 3.30235
# --------
# [day 1] [b_type 80] [num 7] Train model ... 61.65min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1385]	valid_0's mape: 0.0437646	valid_0's SMAPE: 4.52444
# --------
# [day 1] [b_type 80] [num 8] Train model ... 62.21min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1209]	valid_0's mape: 0.0453329	valid_0's SMAPE: 4.68774
# --------
# [day 1] [b_type 80] [num 9] Train model ... 62.66min
# --------
# Training until validation scores don't improve for 100 rounds
# [2000]	valid_0's mape: 0.0495044	valid_0's SMAPE: 5.18773
# Early stopping, best iteration is:
# [1954]	valid_0's mape: 0.049504	valid_0's SMAPE: 5.18769
# --------
# [day 1] [b_type 80] [num 10] Train model ... 63.45min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [788]	valid_0's mape: 0.0537873	valid_0's SMAPE: 5.60225
# --------
# [day 1] [b_type 80] [num 11] Train model ... 63.46min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1036]	valid_0's mape: 0.0377364	valid_0's SMAPE: 3.86943
# --------
# [day 1] [b_type 80] [num 12] Train model ... 63.49min
# --------
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# ...
# ------------------------
# [day 5] [b_type 56] Update Recursive
# ------------------------
# [day 5] [b_type 57] Update Recursive
# ------------------------
# [day 5] [b_type 58] Update Recursive
# ------------------------
# [day 5] [b_type 59] Update Recursive
# ------------------------
# [day 5] [b_type 60] Update Recursive
# ------------------------
# [day 5] [b_type 61] Update Recursive
# ------------------------
# [day 5] [b_type 62] Update Recursive
# ------------------------
# [day 5] [b_type 63] Update Recursive
# ------------------------
# [day 5] [b_type 64] Update Recursive
# ------------------------
# [day 5] [b_type 65] Update Recursive
# ------------------------
# [day 5] [b_type 66] Update Recursive
# ------------------------
# [day 5] [b_type 67] Update Recursive
# ------------------------
# [day 5] [b_type 68] Update Recursive
# ------------------------
# [day 5] [b_type 69] Update Recursive
# ------------------------
# [day 5] [b_type 70] Update Recursive
# ------------------------
# [day 5] [b_type 71] Update Recursive
# ------------------------
# [day 5] [b_type 72] Update Recursive
# ------------------------
# [day 5] [b_type 73] Update Recursive
# ------------------------
# [day 5] [b_type 74] Update Recursive
# ------------------------
# [day 5] [b_type 75] Update Recursive
# ------------------------
# [day 5] [b_type 76] Update Recursive
# ------------------------
# [day 5] [b_type 77] Update Recursive
# ------------------------
# [day 5] [b_type 78] Update Recursive
# ------------------------
# [day 5] [b_type 79] Update Recursive
# ------------------------
# [day 5] [b_type 80] Update Recursive
# ------------------------
# [day 5] [b_type 81] Update Recursive
# ------------------------
# [day 5] [b_type 82] Update Recursive
# ------------------------
# [day 5] [b_type 83] Update Recursive
# ------------------------
# [day 5] [b_type 84] Update Recursive
# ------------------------
# [day 5] [b_type 85] Update Recursive
# ------------------------
# [day 5] [b_type 86] Update Recursive
# ------------------------
# [day 5] [b_type 87] Update Recursive
# ------------------------
# [day 5] [b_type 88] Update Recursive
# ------------------------
# [day 5] [b_type 89] Update Recursive
# ------------------------
# [day 5] [b_type 90] Update Recursive
# ------------------------
# [day 5] [b_type 91] Update Recursive
# ------------------------
# [day 5] [b_type 92] Update Recursive
# ------------------------
# [day 5] [b_type 93] Update Recursive
# ------------------------
# [day 5] [b_type 94] Update Recursive
# ------------------------
# [day 5] [b_type 95] Update Recursive
# ------------------------
# [day 5] [b_type 96] Update Recursive
# ------------------------
# [day 5] [b_type 97] Update Recursive
# ------------------------
# [day 5] [b_type 98] Update Recursive
# ------------------------
# [day 5] [b_type 99] Update Recursive
# ------------------------
# [day 5] [b_type 100] Update Recursive
# ------------------------
# --------
# Done
#
# [day 6] [b_type 1] Update Recursive
# ------------------------
# [day 6] [b_type 2] Update Recursive
# ------------------------
# [day 6] [b_type 3] Update Recursive
# ------------------------
# [day 6] [b_type 4] Update Recursive
# ------------------------
# [day 6] [b_type 5] Update Recursive
# ------------------------
# [day 6] [b_type 6] Update Recursive
# ------------------------
# [day 6] [b_type 7] Update Recursive
# ------------------------
# [day 6] [b_type 8] Update Recursive
# ------------------------
# [day 6] [b_type 9] Update Recursive
# ------------------------
# [day 6] [b_type 10] Update Recursive
# ------------------------
# [day 6] [b_type 11] Update Recursive
# ------------------------
# [day 6] [b_type 12] Update Recursive
# ------------------------
# [day 6] [b_type 13] Update Recursive
# ------------------------
# [day 6] [b_type 14] Update Recursive
# ------------------------
# [day 6] [b_type 15] Update Recursive
# ------------------------
# [day 6] [b_type 16] Update Recursive
# ------------------------
# [day 6] [b_type 17] Update Recursive
# ------------------------
# [day 6] [b_type 18] Update Recursive
# ------------------------
# [day 6] [b_type 19] Update Recursive
# ------------------------
# [day 6] [b_type 20] Update Recursive
# ------------------------
# [day 6] [b_type 21] Update Recursive
# ------------------------
# [day 6] [b_type 22] Update Recursive
# ------------------------
# [day 6] [b_type 23] Update Recursive
# ------------------------
# [day 6] [b_type 24] Update Recursive
# ------------------------
# [day 6] [b_type 25] Update Recursive
# ------------------------
# [day 6] [b_type 26] Update Recursive
# ------------------------
# [day 6] [b_type 27] Update Recursive
# ------------------------
# [day 6] [b_type 28] Update Recursive
# ------------------------
# [day 6] [b_type 29] Update Recursive
# ------------------------
# [day 6] [b_type 30] Update Recursive
# ------------------------
# [day 6] [b_type 31] Update Recursive
# ------------------------
# [day 6] [b_type 32] Update Recursive
# ------------------------
# [day 6] [b_type 33] Update Recursive
# ------------------------
# [day 6] [b_type 34] Update Recursive
# ------------------------
# [day 6] [b_type 35] Update Recursive
# ------------------------
# [day 6] [b_type 36] Update Recursive
# ------------------------
# [day 6] [b_type 37] Update Recursive
# ------------------------
# [day 6] [b_type 38] Update Recursive
# ------------------------
# [day 6] [b_type 39] Update Recursive
# ------------------------
# [day 6] [b_type 40] Update Recursive
# ------------------------
# [day 6] [b_type 41] Update Recursive
# ------------------------
# [day 6] [b_type 42] Update Recursive
# ------------------------
# [day 6] [b_type 43] Update Recursive
# ------------------------
# [day 6] [b_type 44] Update Recursive
# ------------------------
# [day 6] [b_type 45] Update Recursive
# ------------------------
# [day 6] [b_type 46] Update Recursive
# ------------------------
# [day 6] [b_type 47] Update Recursive
# ------------------------
# [day 6] [b_type 48] Update Recursive
# ------------------------
# [day 6] [b_type 49] Update Recursive
# ------------------------
# [day 6] [b_type 50] Update Recursive
# ------------------------
# [day 6] [b_type 51] Update Recursive
# ------------------------
# [day 6] [b_type 52] Update Recursive
# ------------------------
# [day 6] [b_type 53] Update Recursive
# ------------------------
# [day 6] [b_type 54] Update Recursive
# ------------------------
# [day 6] [b_type 55] Update Recursive
# ------------------------
# [day 6] [b_type 56] Update Recursive
# ------------------------
# [day 6] [b_type 57] Update Recursive
# ------------------------
# [day 6] [b_type 58] Update Recursive
# ------------------------
# [day 6] [b_type 59] Update Recursive
# ------------------------
# [day 6] [b_type 60] Update Recursive
# ------------------------
# [day 6] [b_type 61] Update Recursive
# ------------------------
# [day 6] [b_type 62] Update Recursive
# ------------------------
# [day 6] [b_type 63] Update Recursive
# ------------------------
# [day 6] [b_type 64] Update Recursive
# ------------------------
# [day 6] [b_type 65] Update Recursive
# ------------------------
# [day 6] [b_type 66] Update Recursive
# ------------------------
# [day 6] [b_type 67] Update Recursive
# ------------------------
# [day 6] [b_type 68] Update Recursive
# ------------------------
# [day 6] [b_type 69] Update Recursive
# ------------------------
# [day 6] [b_type 70] Update Recursive
# ------------------------
# [day 6] [b_type 71] Update Recursive
# ------------------------
# [day 6] [b_type 72] Update Recursive
# ------------------------
# [day 6] [b_type 73] Update Recursive
# ------------------------
# [day 6] [b_type 74] Update Recursive
# ------------------------
# [day 6] [b_type 75] Update Recursive
# ------------------------
# [day 6] [b_type 76] Update Recursive
# ------------------------
# [day 6] [b_type 77] Update Recursive
# ------------------------
# [day 6] [b_type 78] Update Recursive
# ------------------------
# [day 6] [b_type 79] Update Recursive
# ------------------------
# [day 6] [b_type 80] Update Recursive
# ------------------------
# [day 6] [b_type 81] Update Recursive
# ------------------------
# [day 6] [b_type 82] Update Recursive
# ------------------------
# [day 6] [b_type 83] Update Recursive
# ------------------------
# [day 6] [b_type 84] Update Recursive
# ------------------------
# [day 6] [b_type 85] Update Recursive
# ------------------------
# [day 6] [b_type 86] Update Recursive
# ------------------------
# [day 6] [b_type 87] Update Recursive
# ------------------------
# [day 6] [b_type 88] Update Recursive
# ------------------------
# [day 6] [b_type 89] Update Recursive
# ------------------------
# [day 6] [b_type 90] Update Recursive
# ------------------------
# [day 6] [b_type 91] Update Recursive
# ------------------------
# [day 6] [b_type 92] Update Recursive
# ------------------------
# [day 6] [b_type 93] Update Recursive
# ------------------------
# [day 6] [b_type 94] Update Recursive
# ------------------------
# [day 6] [b_type 95] Update Recursive
# ------------------------
# [day 6] [b_type 96] Update Recursive
# ------------------------
# [day 6] [b_type 97] Update Recursive
# ------------------------
# [day 6] [b_type 98] Update Recursive
# ------------------------
# [day 6] [b_type 99] Update Recursive
# ------------------------
# [day 6] [b_type 100] Update Recursive
# ------------------------
# --------
# Done
#
# [day 7] [b_type 1] Update Recursive
# ------------------------
# [day 7] [b_type 2] Update Recursive
# ------------------------
# [day 7] [b_type 3] Update Recursive
# ------------------------
# [day 7] [b_type 4] Update Recursive
# ------------------------
# [day 7] [b_type 5] Update Recursive
# ------------------------
# [day 7] [b_type 6] Update Recursive
# ------------------------
# [day 7] [b_type 7] Update Recursive
# ------------------------
# [day 7] [b_type 8] Update Recursive
# ------------------------
# [day 7] [b_type 9] Update Recursive
# ------------------------
# [day 7] [b_type 10] Update Recursive
# ------------------------
# [day 7] [b_type 11] Update Recursive
# ------------------------
# [day 7] [b_type 12] Update Recursive
# ------------------------
# [day 7] [b_type 13] Update Recursive
# ------------------------
# [day 7] [b_type 14] Update Recursive
# ------------------------
# [day 7] [b_type 15] Update Recursive
# ------------------------
# [day 7] [b_type 16] Update Recursive
# ------------------------
# [day 7] [b_type 17] Update Recursive
# ------------------------
# [day 7] [b_type 18] Update Recursive
# ------------------------
# [day 7] [b_type 19] Update Recursive
# ------------------------
# [day 7] [b_type 20] Update Recursive
# ------------------------
# [day 7] [b_type 21] Update Recursive
# ------------------------
# [day 7] [b_type 22] Update Recursive
# ------------------------
# [day 7] [b_type 23] Update Recursive
# ------------------------
# [day 7] [b_type 24] Update Recursive
# ------------------------
# [day 7] [b_type 25] Update Recursive
# ------------------------
# [day 7] [b_type 26] Update Recursive
# ------------------------
# [day 7] [b_type 27] Update Recursive
# ------------------------
# [day 7] [b_type 28] Update Recursive
# ------------------------
# [day 7] [b_type 29] Update Recursive
# ------------------------
# [day 7] [b_type 30] Update Recursive
# ------------------------
# [day 7] [b_type 31] Update Recursive
# ------------------------
# [day 7] [b_type 32] Update Recursive
# ------------------------
# [day 7] [b_type 33] Update Recursive
# ------------------------
# [day 7] [b_type 34] Update Recursive
# ------------------------
# [day 7] [b_type 35] Update Recursive
# ------------------------
# [day 7] [b_type 36] Update Recursive
# ------------------------
# [day 7] [b_type 37] Update Recursive
# ------------------------
# [day 7] [b_type 38] Update Recursive
# ------------------------
# [day 7] [b_type 39] Update Recursive
# ------------------------
# [day 7] [b_type 40] Update Recursive
# ------------------------
# [day 7] [b_type 41] Update Recursive
# ------------------------
# [day 7] [b_type 42] Update Recursive
# ------------------------
# [day 7] [b_type 43] Update Recursive
# ------------------------
# [day 7] [b_type 44] Update Recursive
# ------------------------
# [day 7] [b_type 45] Update Recursive
# ------------------------
# [day 7] [b_type 46] Update Recursive
# ------------------------
# [day 7] [b_type 47] Update Recursive
# ------------------------
# [day 7] [b_type 48] Update Recursive
# ------------------------
# [day 7] [b_type 49] Update Recursive
# ------------------------
# [day 7] [b_type 50] Update Recursive
# ------------------------
# [day 7] [b_type 51] Update Recursive
# ------------------------
# [day 7] [b_type 52] Update Recursive
# ------------------------
# [day 7] [b_type 53] Update Recursive
# ------------------------
# [day 7] [b_type 54] Update Recursive
# ------------------------
# [day 7] [b_type 55] Update Recursive
# ------------------------
# [day 7] [b_type 56] Update Recursive
# ------------------------
# [day 7] [b_type 57] Update Recursive
# ------------------------
# [day 7] [b_type 58] Update Recursive
# ------------------------
# [day 7] [b_type 59] Update Recursive
# ------------------------
# [day 7] [b_type 60] Update Recursive
# ------------------------
# [day 7] [b_type 61] Update Recursive
# ------------------------
# [day 7] [b_type 62] Update Recursive
# ------------------------
# [day 7] [b_type 63] Update Recursive
# ------------------------
# [day 7] [b_type 64] Update Recursive
# ------------------------
# [day 7] [b_type 65] Update Recursive
# ------------------------
# [day 7] [b_type 66] Update Recursive
# ------------------------
# [day 7] [b_type 67] Update Recursive
# ------------------------
# [day 7] [b_type 68] Update Recursive
# ------------------------
# [day 7] [b_type 69] Update Recursive
# ------------------------
# [day 7] [b_type 70] Update Recursive
# ------------------------
# [day 7] [b_type 71] Update Recursive
# ------------------------
# [day 7] [b_type 72] Update Recursive
# ------------------------
# [day 7] [b_type 73] Update Recursive
# ------------------------
# [day 7] [b_type 74] Update Recursive
# ------------------------
# [day 7] [b_type 75] Update Recursive
# ------------------------
# [day 7] [b_type 76] Update Recursive
# ------------------------
# [day 7] [b_type 77] Update Recursive
# ------------------------
# [day 7] [b_type 78] Update Recursive
# ------------------------
# [day 7] [b_type 79] Update Recursive
# ------------------------
# [day 7] [b_type 80] Update Recursive
# ------------------------
# [day 7] [b_type 81] Update Recursive
# ------------------------
# [day 7] [b_type 82] Update Recursive
# ------------------------
# [day 7] [b_type 83] Update Recursive
# ------------------------
# [day 7] [b_type 84] Update Recursive
# ------------------------
# [day 7] [b_type 85] Update Recursive
# ------------------------
# [day 7] [b_type 86] Update Recursive
# ------------------------
# [day 7] [b_type 87] Update Recursive
# ------------------------
# [day 7] [b_type 88] Update Recursive
# ------------------------
# [day 7] [b_type 89] Update Recursive
# ------------------------
# [day 7] [b_type 90] Update Recursive
# ------------------------
# [day 7] [b_type 91] Update Recursive
# ------------------------
# [day 7] [b_type 92] Update Recursive
# ------------------------
# [day 7] [b_type 93] Update Recursive
# ------------------------
# [day 7] [b_type 94] Update Recursive
# ------------------------
# [day 7] [b_type 95] Update Recursive
# ------------------------
# [day 7] [b_type 96] Update Recursive
# ------------------------
# [day 7] [b_type 97] Update Recursive
# ------------------------
# [day 7] [b_type 98] Update Recursive
# ------------------------
# [day 7] [b_type 99] Update Recursive
# ------------------------
# [day 7] [b_type 100] Update Recursive
# ------------------------
# --------
# Done
#
# final_val_SMAPE : 6.2910119612167135
# --------
#          num_date_time  month  day  time       answer
# 0        1_20220825 00      8   25     0  1965.626490
# 1        1_20220825 01      8   25     1  1910.975698
# 2        1_20220825 02      8   25     2  1794.561720
# 3        1_20220825 03      8   25     3  1699.175230
# 4        1_20220825 04      8   25     4  1717.304688
# ...                ...    ...  ...   ...          ...
# 16795  100_20220831 19      8   31    19   870.565485
# 16796  100_20220831 20      8   31    20   763.572874
# 16797  100_20220831 21      8   31    21   709.570542
# 16798  100_20220831 22      8   31    22   591.059985
# 16799  100_20220831 23      8   31    23   511.612557
#
# [16800 rows x 5 columns]

# %%
Recursive_ans[['num_date_time','answer']].to_csv(f"{root_path}/my_submission_LGBM_Final.csv", index=False)

# %%
# plot_series
plot_df = pd.concat([train,test],axis=0, ignore_index=True)
plot_df = plot_df[plot_df['num_date_time'].isin(Recursive_ans['num_date_time'])]
plot_df.loc[:,'Recursive_ans'] = Recursive_ans['answer'].values
for i in range(100):
    train_data = train_0[train_0['건물번호']==i+1]['전력소비량(kWh)']
    valid_data = valid_0[valid_0['건물번호']==i+1]['전력소비량(kWh)']
    rc_test_data = plot_df[plot_df['건물번호']==i+1]['Recursive_ans']
    plot_series(train_data, valid_data, rc_test_data, markers=[',' , ',' , ','], title=f"b_type: {i+1}")
